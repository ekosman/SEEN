# %%
# %matplotlib widget
# %matplotlib inline
import torch
import torch.nn as nn
import pickle
import time
import copy
import os
from queue import LifoQueue
from sklearn.cluster import DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.metrics import davies_bouldin_score
from scipy.stats import kurtosis
import matplotlib.pyplot as plt
import numpy as np
import sys
from sklearn.tree import DecisionTreeClassifier
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from tqdm.notebook import tqdm
from sklearn.metrics import pairwise_distances
import network.cpc
from network.cpc import CDCK2
from utils.MatplotlibUtils import reduce_dims_and_plot
from utils.ClassificationUtiols import onehot_coding
from soft_decision_tree.sdt_model import SDT
from sklearn import tree as tt

# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Load the model and the dataset

# %%
model_path = r'/home/eitan.k/EntangledExplainableClustering/knn_loss_batch_512_k_256/models/epoch_45.pt'
dataset_path = r'/home/eitan.k/EntangledExplainableClustering/knn_loss_batch_512_k_256/data/test_data_protocol_4.file'

print(f"Load the model from: {model_path}")
model = torch.load(model_path, map_location='cpu')

with open(dataset_path, 'rb') as fp:
    dataset = pickle.load(fp)

all_sensors = dataset.dataset.all_signals    
print(f"sensor names: ({len(all_sensors)} total)")

for s in all_sensors:
    print(f"- {s}")
    
print(f"Multihorizon size of the model: {model.timestep}")
print(f"Test split ratio: {len(dataset) / len(dataset.dataset)}")
print(f"Total number of windows in the dataset (without splitting): {len(dataset.dataset)}")
# Out:
# Load the model from: /home/eitan.k/EntangledExplainableClustering/knn_loss_batch_512_k_256/models/epoch_45.pt
# sensor names: (18 total)
# - speed
# - steering_angle
# - wheel_speed_0
# - wheel_speed_1
# - wheel_speed_2
# - wheel_speed_3
# - accelerometer_0
# - accelerometer_1
# - accelerometer_2
# - gyro_0
# - gyro_1
# - gyro_2
# - gyro_bias_0
# - gyro_bias_1
# - gyro_bias_2
# - gyro_uncalibrated_0
# - gyro_uncalibrated_1
# - gyro_uncalibrated_2
# Multihorizon size of the model: 30
# Test split ratio: 0.2
# Total number of windows in the dataset (without splitting): 101465

# %%
batch_size = 500
loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Extract representations

# %%
projections = torch.tensor([])
samples = torch.tensor([])
device = 'cuda'
model = model.to(device).eval()

with torch.no_grad():
    bar = tqdm(total=len(loader.dataset))
    for batch in loader:
        hidden = CDCK2.init_hidden(len(batch))
        batch = batch.to(device)
        hidden = hidden.to(device)

        y = model.predict(batch, hidden).detach().cpu()
        projections = torch.cat([projections, y.detach().cpu()])
        samples = torch.cat([samples, batch.detach().cpu()])
        bar.update(y.shape[0])
# Out:
#   0%|          | 0/20293 [00:00<?, ?it/s]

# %% [markdown]
# # Fit GMM and calculate indices

# %%
scores = []
best_score = float('inf')
clusters = None
range_ = list(range(2, 30))
for k in tqdm(range_):
    y = GaussianMixture(n_components=k).fit_predict(projections)
    cur_score = davies_bouldin_score(projections, y)
    scores.append(cur_score)
    
    if cur_score < best_score:
        best_score = cur_score
        clusters = y
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]

# %%
plt.figure()
plt.xlabel('Number of clusters')
plt.ylabel('DB Score')
plt.plot(range_, scores)
best_k = range_[np.argmin(scores)]
plt.axvline(best_k, color='r')
plt.show()

labels = set(clusters)
print(labels)
# Out:
# {0, 1}

# %%
distances = pairwise_distances(projections)
# distances = np.triu(distances)
distances_f = distances.flatten()

plt.matshow(distances)
plt.colorbar()
plt.figure()
plt.hist(distances_f[distances_f > 0], bins=1000)
plt.show()

# %% [markdown]
# # Visualize with T-SNE

# %%
perplexity = 200

p = reduce_dims_and_plot(projections,
                         y=clusters,
                         title=f'perplexity: {perplexity}',
                         file_name=None,
                         perplexity=perplexity,
                         library='Multicore-TSNE',
                         perform_PCA=False,
                         projected=None,
                         figure_type='2d',
                         show_figure=True,
                         close_figure=False,
                         text=None)

# %% [markdown]
# # Train a Soft-Decision-Tree given the self-labels

# %% [markdown]
# ## Prepare the dataset

# %%
# unnormalized_samples = samples.clone()

# for col, sensor in enumerate(tqdm(dataset.dataset.all_signals)):
#     denormalizer = dataset.dataset.get_denormalization_for_sensor(sensor)
#     unnormalized_samples[:, col, :] = denormalizer(unnormalized_samples[:, col, :])

sampled = samples[..., range(0, samples.shape[-1], 200)]

samples_f = sampled.flatten(1)
tree_dataset = list(zip(samples_f, clusters))
batch_size = 2000
tree_loader = torch.utils.data.DataLoader(tree_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # Define how we prune the weights of a node

# %%
def prune_node(node_weights, factor=1):
    w = node_weights.cpu().detach().numpy()
    mean_ = np.mean(w)
    std_ = np.std(w)
    node_weights[((mean_ - std_ * factor) < node_weights) & (node_weights < (mean_ + std_ * factor))] = 0
    return node_weights

def prune_node_keep(node_weights, keep=4):
    w = node_weights.cpu().detach().numpy()
    throw_idx = np.argsort(abs(w))[:-keep]
    node_weights[throw_idx] = 0
    return node_weights

def prune_tree(tree_, factor):
    new_weights = tree_.inner_nodes.weight.clone()
    for i in range(new_weights.shape[0]):
        res = prune_node_keep(new_weights[i, :], factor)
        new_weights[i, :] = res

    with torch.no_grad():
        tree_.inner_nodes.weight.copy_(new_weights)
        
def sparseness(x):
    s = []
    for i in range(x.shape[0]):
        x_ = x[i, :]
        sp = (len(x_) - torch.norm(x_, 0).item()) / len(x_)
        s.append(sp)
    return np.mean(s)

def compute_regularization_by_level(tree):
    total_reg = 0
    for i in range(tree.inner_nodes.weight.shape[0]):
        cur_level = np.floor(np.log2(i+1))
        node_reg = torch.norm(tree.inner_nodes.weight[i].view(-1), 2)
        total_reg += 2**(-cur_level) * node_reg
    return total_reg

def show_sparseness(tree):
    avg_sp = sparseness(tree.inner_nodes.weight)
    print(f"Average sparseness: {avg_sp}")
    layer = 0
    sps = []
    for i in range(tree.inner_nodes.weight.shape[0]):
        cur_layer = int(np.floor(np.log2(i+1)))
        if cur_layer != layer:
            print(f"layer {layer}: {np.mean(sps)}")
            sps = []
            layer = cur_layer

        x_ = tree.inner_nodes.weight[i, :]
        sp = (len(x_) - torch.norm(x_, 0).item()) / len(x_)
        sps.append(sp)
        
    return avg_sp

# %% [markdown]
# ## Training configurations

# %%
def do_epoch(model, loader, device, log_interval, losses, accs, epoch, iteration):
    model = model.train()
    for batch_idx, (data, target) in enumerate(loader):
        iteration += 1
        data, target = data.to(device), target.to(device)

        output, penalty = tree.forward(data)

        # Loss
        loss_tree = criterion(output, target.view(-1))

        # Penalty
        loss_tree += penalty

        # Sparse regularization
#         fc_params = torch.cat([x.view(-1) for x in tree.inner_nodes.parameters()])
#         regularization = sparsity_lamda * torch.norm(fc_params, 2)
        regularization = sparsity_lamda * compute_regularization_by_level(tree)
        loss = loss_tree

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        losses.append(loss.item())

        pred = output.data.max(1)[1]
        correct = pred.eq(target.view(-1).data).sum()
        accs.append(correct.item() / data.size()[0])

        # Print training status
        if batch_idx % log_interval == 0:
            print(f"Epoch: {epoch:02d} | Batch: {batch_idx:03d} / {len(loader):03d} | Total loss: {loss.item():.3f} | Reg loss: {regularization.item():.3f} | Tree loss: {loss_tree.item():.3f} | Accuracy: {correct.item() / data.size()[0]:03f} | {round((time.time() - start_time) / iteration, 3)} sec/iter")
            
    return iteration

# %%
lr = 5e-3
weight_decay = 5e-4
sparsity_lamda = 2e-3
epochs = 500
output_dim = len(set(clusters))
log_interval = 1
tree_depth = 10

# %%
tree = SDT(input_dim=samples_f.shape[1], output_dim=len(labels), depth=tree_depth, lamda=1e-3, use_cuda=True)
optimizer = torch.optim.Adam(tree.parameters(),
                                 lr=lr,
                                 weight_decay=weight_decay)
criterion = nn.CrossEntropyLoss()
tree = tree.to(device)
clf = DecisionTreeClassifier(max_depth=tree_depth).fit(samples_f, clusters)
print(f"DT accuracy: {clf.score(samples_f, clusters)}")
tree.initialize_from_decision_tree(clf)
# Out:
# DT accuracy: 0.9921155078105751

# %%
losses = []
accs = []
sparsity = []

# %%
start_time = time.time()
iteration = 0
for epoch in range(epochs):
    # Training
    avg_sp = show_sparseness(tree)
    sparsity.append(avg_sp)
    iteration = do_epoch(tree, tree_loader, device, log_interval, losses, accs, epoch, iteration)
    
    if epoch % 1 == 0:
        prune_tree(tree, factor=5)
# Out:
# Average sparseness: 0.15467453000869505
# layer 0: 0.988950276243094
# layer 1: 0.988950276243094
# layer 2: 0.7417127071823204
# layer 3: 0.7417127071823204
# layer 4: 0.6799033149171271
# layer 5: 0.587189226519337
# layer 6: 0.4172133977900553
# layer 7: 0.2472375690607735
# layer 8: 0.11975569751381217
# Epoch: 00 | Batch: 000 / 011 | Total loss: 0.701 | Reg loss: 0.017 | Tree loss: 0.701 | Accuracy: 0.584000 | 1.536 sec/iter
# Epoch: 00 | Batch: 001 / 011 | Total loss: 0.701 | Reg loss: 0.017 | Tree loss: 0.701 | Accuracy: 0.510500 | 1.461 sec/iter
# Epoch: 00 | Batch: 002 / 011 | Total loss: 0.699 | Reg loss: 0.017 | Tree loss: 0.699 | Accuracy: 0.520500 | 1.434 sec/iter
# Epoch: 00 | Batch: 003 / 011 | Total loss: 0.697 | Reg loss: 0.016 | Tree loss: 0.697 | Accuracy: 0.521500 | 1.341 sec/iter
# Epoch: 00 | Batch: 004 / 011 | Total loss: 0.692 | Reg loss: 0.016 | Tree loss: 0.692 | Accuracy: 0.552500 | 1.338 sec/iter
# Epoch: 00 | Batch: 005 / 011 | Total loss: 0.692 | Reg loss: 0.015 | Tree loss: 0.692 | Accuracy: 0.556500 | 1.34 sec/iter
# Epoch: 00 | Batch: 006 / 011 | Total loss: 0.689 | Reg loss: 0.015 | Tree loss: 0.689 | Accuracy: 0.581500 | 1.342 sec/iter
# Epoch: 00 | Batch: 007 / 011 | Total loss: 0.689 | Reg loss: 0.015 | Tree loss: 0.689 | Accuracy: 0.562500 | 1.342 sec/iter
# Epoch: 00 | Batch: 008 / 011 | Total loss: 0.686 | Reg loss: 0.015 | Tree loss: 0.686 | Accuracy: 0.578000 | 1.342 sec/iter
# Epoch: 00 | Batch: 009 / 011 | Total loss: 0.688 | Reg loss: 0.014 | Tree loss: 0.688 | Accuracy: 0.571000 | 1.342 sec/iter
# Epoch: 00 | Batch: 010 / 011 | Total loss: 0.689 | Reg loss: 0.014 | Tree loss: 0.689 | Accuracy: 0.569966 | 1.3 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 01 | Batch: 000 / 011 | Total loss: 0.698 | Reg loss: 0.013 | Tree loss: 0.698 | Accuracy: 0.635000 | 1.344 sec/iter
# Epoch: 01 | Batch: 001 / 011 | Total loss: 0.697 | Reg loss: 0.013 | Tree loss: 0.697 | Accuracy: 0.668000 | 1.344 sec/iter
# Epoch: 01 | Batch: 002 / 011 | Total loss: 0.691 | Reg loss: 0.013 | Tree loss: 0.691 | Accuracy: 0.659500 | 1.343 sec/iter
# Epoch: 01 | Batch: 003 / 011 | Total loss: 0.689 | Reg loss: 0.013 | Tree loss: 0.689 | Accuracy: 0.598500 | 1.323 sec/iter
# Epoch: 01 | Batch: 004 / 011 | Total loss: 0.690 | Reg loss: 0.013 | Tree loss: 0.690 | Accuracy: 0.565500 | 1.323 sec/iter
# Epoch: 01 | Batch: 005 / 011 | Total loss: 0.688 | Reg loss: 0.013 | Tree loss: 0.688 | Accuracy: 0.565500 | 1.324 sec/iter
# Epoch: 01 | Batch: 006 / 011 | Total loss: 0.690 | Reg loss: 0.013 | Tree loss: 0.690 | Accuracy: 0.547500 | 1.327 sec/iter
# Epoch: 01 | Batch: 007 / 011 | Total loss: 0.689 | Reg loss: 0.014 | Tree loss: 0.689 | Accuracy: 0.554000 | 1.328 sec/iter
# Epoch: 01 | Batch: 008 / 011 | Total loss: 0.684 | Reg loss: 0.014 | Tree loss: 0.684 | Accuracy: 0.585500 | 1.329 sec/iter
# Epoch: 01 | Batch: 009 / 011 | Total loss: 0.685 | Reg loss: 0.014 | Tree loss: 0.685 | Accuracy: 0.585500 | 1.33 sec/iter
# Epoch: 01 | Batch: 010 / 011 | Total loss: 0.679 | Reg loss: 0.014 | Tree loss: 0.679 | Accuracy: 0.627986 | 1.309 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 02 | Batch: 000 / 011 | Total loss: 0.697 | Reg loss: 0.013 | Tree loss: 0.697 | Accuracy: 0.643500 | 1.331 sec/iter
# Epoch: 02 | Batch: 001 / 011 | Total loss: 0.693 | Reg loss: 0.013 | Tree loss: 0.693 | Accuracy: 0.667500 | 1.33 sec/iter
# Epoch: 02 | Batch: 002 / 011 | Total loss: 0.692 | Reg loss: 0.013 | Tree loss: 0.692 | Accuracy: 0.685000 | 1.328 sec/iter
# Epoch: 02 | Batch: 003 / 011 | Total loss: 0.689 | Reg loss: 0.013 | Tree loss: 0.689 | Accuracy: 0.711500 | 1.323 sec/iter
# Epoch: 02 | Batch: 004 / 011 | Total loss: 0.689 | Reg loss: 0.013 | Tree loss: 0.689 | Accuracy: 0.647500 | 1.322 sec/iter
# Epoch: 02 | Batch: 005 / 011 | Total loss: 0.687 | Reg loss: 0.013 | Tree loss: 0.687 | Accuracy: 0.614000 | 1.323 sec/iter
# Epoch: 02 | Batch: 006 / 011 | Total loss: 0.686 | Reg loss: 0.013 | Tree loss: 0.686 | Accuracy: 0.596500 | 1.324 sec/iter
# Epoch: 02 | Batch: 007 / 011 | Total loss: 0.683 | Reg loss: 0.013 | Tree loss: 0.683 | Accuracy: 0.584000 | 1.325 sec/iter
# Epoch: 02 | Batch: 008 / 011 | Total loss: 0.682 | Reg loss: 0.013 | Tree loss: 0.682 | Accuracy: 0.580000 | 1.325 sec/iter
# Epoch: 02 | Batch: 009 / 011 | Total loss: 0.693 | Reg loss: 0.013 | Tree loss: 0.693 | Accuracy: 0.554500 | 1.326 sec/iter
# Epoch: 02 | Batch: 010 / 011 | Total loss: 0.692 | Reg loss: 0.013 | Tree loss: 0.692 | Accuracy: 0.563140 | 1.312 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 03 | Batch: 000 / 011 | Total loss: 0.699 | Reg loss: 0.012 | Tree loss: 0.699 | Accuracy: 0.639500 | 1.328 sec/iter
# Epoch: 03 | Batch: 001 / 011 | Total loss: 0.695 | Reg loss: 0.012 | Tree loss: 0.695 | Accuracy: 0.666000 | 1.327 sec/iter
# Epoch: 03 | Batch: 002 / 011 | Total loss: 0.692 | Reg loss: 0.012 | Tree loss: 0.692 | Accuracy: 0.705000 | 1.326 sec/iter
# Epoch: 03 | Batch: 003 / 011 | Total loss: 0.691 | Reg loss: 0.012 | Tree loss: 0.691 | Accuracy: 0.728500 | 1.317 sec/iter
# Epoch: 03 | Batch: 004 / 011 | Total loss: 0.688 | Reg loss: 0.012 | Tree loss: 0.688 | Accuracy: 0.692500 | 1.318 sec/iter
# Epoch: 03 | Batch: 005 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.622500 | 1.318 sec/iter
# Epoch: 03 | Batch: 006 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.584000 | 1.32 sec/iter
# Epoch: 03 | Batch: 007 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.571500 | 1.321 sec/iter
# Epoch: 03 | Batch: 008 / 011 | Total loss: 0.687 | Reg loss: 0.012 | Tree loss: 0.687 | Accuracy: 0.562500 | 1.321 sec/iter
# Epoch: 03 | Batch: 009 / 011 | Total loss: 0.684 | Reg loss: 0.012 | Tree loss: 0.684 | Accuracy: 0.569000 | 1.321 sec/iter
# Epoch: 03 | Batch: 010 / 011 | Total loss: 0.676 | Reg loss: 0.012 | Tree loss: 0.676 | Accuracy: 0.590444 | 1.311 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 04 | Batch: 000 / 011 | Total loss: 0.695 | Reg loss: 0.012 | Tree loss: 0.695 | Accuracy: 0.656000 | 1.322 sec/iter
# Epoch: 04 | Batch: 001 / 011 | Total loss: 0.694 | Reg loss: 0.012 | Tree loss: 0.694 | Accuracy: 0.663000 | 1.322 sec/iter
# Epoch: 04 | Batch: 002 / 011 | Total loss: 0.690 | Reg loss: 0.012 | Tree loss: 0.690 | Accuracy: 0.702000 | 1.322 sec/iter
# Epoch: 04 | Batch: 003 / 011 | Total loss: 0.688 | Reg loss: 0.012 | Tree loss: 0.688 | Accuracy: 0.629500 | 1.316 sec/iter
# Epoch: 04 | Batch: 004 / 011 | Total loss: 0.688 | Reg loss: 0.012 | Tree loss: 0.688 | Accuracy: 0.607500 | 1.316 sec/iter
# Epoch: 04 | Batch: 005 / 011 | Total loss: 0.687 | Reg loss: 0.012 | Tree loss: 0.687 | Accuracy: 0.590000 | 1.316 sec/iter
# Epoch: 04 | Batch: 006 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.579000 | 1.317 sec/iter
# Epoch: 04 | Batch: 007 / 011 | Total loss: 0.687 | Reg loss: 0.012 | Tree loss: 0.687 | Accuracy: 0.566500 | 1.317 sec/iter
# Epoch: 04 | Batch: 008 / 011 | Total loss: 0.685 | Reg loss: 0.012 | Tree loss: 0.685 | Accuracy: 0.584000 | 1.318 sec/iter
# Epoch: 04 | Batch: 009 / 011 | Total loss: 0.685 | Reg loss: 0.012 | Tree loss: 0.685 | Accuracy: 0.577000 | 1.319 sec/iter
# Epoch: 04 | Batch: 010 / 011 | Total loss: 0.678 | Reg loss: 0.012 | Tree loss: 0.678 | Accuracy: 0.587031 | 1.311 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 05 | Batch: 000 / 011 | Total loss: 0.695 | Reg loss: 0.012 | Tree loss: 0.695 | Accuracy: 0.665000 | 1.32 sec/iter
# Epoch: 05 | Batch: 001 / 011 | Total loss: 0.695 | Reg loss: 0.012 | Tree loss: 0.695 | Accuracy: 0.679500 | 1.32 sec/iter
# Epoch: 05 | Batch: 002 / 011 | Total loss: 0.693 | Reg loss: 0.012 | Tree loss: 0.693 | Accuracy: 0.682500 | 1.32 sec/iter
# Epoch: 05 | Batch: 003 / 011 | Total loss: 0.691 | Reg loss: 0.012 | Tree loss: 0.691 | Accuracy: 0.700500 | 1.315 sec/iter
# Epoch: 05 | Batch: 004 / 011 | Total loss: 0.690 | Reg loss: 0.012 | Tree loss: 0.690 | Accuracy: 0.653500 | 1.315 sec/iter
# Epoch: 05 | Batch: 005 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.625000 | 1.316 sec/iter
# Epoch: 05 | Batch: 006 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.592000 | 1.317 sec/iter
# Epoch: 05 | Batch: 007 / 011 | Total loss: 0.684 | Reg loss: 0.012 | Tree loss: 0.684 | Accuracy: 0.596500 | 1.317 sec/iter
# Epoch: 05 | Batch: 008 / 011 | Total loss: 0.683 | Reg loss: 0.012 | Tree loss: 0.683 | Accuracy: 0.595000 | 1.317 sec/iter
# Epoch: 05 | Batch: 009 / 011 | Total loss: 0.684 | Reg loss: 0.012 | Tree loss: 0.684 | Accuracy: 0.581000 | 1.318 sec/iter
# Epoch: 05 | Batch: 010 / 011 | Total loss: 0.671 | Reg loss: 0.012 | Tree loss: 0.671 | Accuracy: 0.614334 | 1.311 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 06 | Batch: 000 / 011 | Total loss: 0.696 | Reg loss: 0.012 | Tree loss: 0.696 | Accuracy: 0.665000 | 1.319 sec/iter
# Epoch: 06 | Batch: 001 / 011 | Total loss: 0.695 | Reg loss: 0.012 | Tree loss: 0.695 | Accuracy: 0.691500 | 1.319 sec/iter
# Epoch: 06 | Batch: 002 / 011 | Total loss: 0.690 | Reg loss: 0.012 | Tree loss: 0.690 | Accuracy: 0.712500 | 1.319 sec/iter
# Epoch: 06 | Batch: 003 / 011 | Total loss: 0.688 | Reg loss: 0.012 | Tree loss: 0.688 | Accuracy: 0.631000 | 1.314 sec/iter
# Epoch: 06 | Batch: 004 / 011 | Total loss: 0.689 | Reg loss: 0.012 | Tree loss: 0.689 | Accuracy: 0.599000 | 1.315 sec/iter
# Epoch: 06 | Batch: 005 / 011 | Total loss: 0.682 | Reg loss: 0.012 | Tree loss: 0.682 | Accuracy: 0.600500 | 1.315 sec/iter
# Epoch: 06 | Batch: 006 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.573500 | 1.316 sec/iter
# Epoch: 06 | Batch: 007 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.557000 | 1.316 sec/iter
# Epoch: 06 | Batch: 008 / 011 | Total loss: 0.688 | Reg loss: 0.012 | Tree loss: 0.688 | Accuracy: 0.556500 | 1.317 sec/iter
# Epoch: 06 | Batch: 009 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.568000 | 1.317 sec/iter
# Epoch: 06 | Batch: 010 / 011 | Total loss: 0.670 | Reg loss: 0.012 | Tree loss: 0.670 | Accuracy: 0.634812 | 1.312 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 07 | Batch: 000 / 011 | Total loss: 0.691 | Reg loss: 0.012 | Tree loss: 0.691 | Accuracy: 0.664500 | 1.318 sec/iter
# Epoch: 07 | Batch: 001 / 011 | Total loss: 0.694 | Reg loss: 0.012 | Tree loss: 0.694 | Accuracy: 0.661000 | 1.318 sec/iter
# Epoch: 07 | Batch: 002 / 011 | Total loss: 0.695 | Reg loss: 0.012 | Tree loss: 0.695 | Accuracy: 0.683500 | 1.318 sec/iter
# Epoch: 07 | Batch: 003 / 011 | Total loss: 0.691 | Reg loss: 0.012 | Tree loss: 0.691 | Accuracy: 0.734500 | 1.314 sec/iter
# Epoch: 07 | Batch: 004 / 011 | Total loss: 0.688 | Reg loss: 0.012 | Tree loss: 0.688 | Accuracy: 0.726000 | 1.314 sec/iter
# Epoch: 07 | Batch: 005 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.668000 | 1.315 sec/iter
# Epoch: 07 | Batch: 006 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.609500 | 1.315 sec/iter
# Epoch: 07 | Batch: 007 / 011 | Total loss: 0.688 | Reg loss: 0.012 | Tree loss: 0.688 | Accuracy: 0.574500 | 1.316 sec/iter
# Epoch: 07 | Batch: 008 / 011 | Total loss: 0.684 | Reg loss: 0.012 | Tree loss: 0.684 | Accuracy: 0.582500 | 1.316 sec/iter
# Epoch: 07 | Batch: 009 / 011 | Total loss: 0.682 | Reg loss: 0.012 | Tree loss: 0.682 | Accuracy: 0.585000 | 1.316 sec/iter
# Epoch: 07 | Batch: 010 / 011 | Total loss: 0.676 | Reg loss: 0.012 | Tree loss: 0.676 | Accuracy: 0.600683 | 1.311 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 08 | Batch: 000 / 011 | Total loss: 0.695 | Reg loss: 0.012 | Tree loss: 0.695 | Accuracy: 0.686000 | 1.317 sec/iter
# Epoch: 08 | Batch: 001 / 011 | Total loss: 0.692 | Reg loss: 0.012 | Tree loss: 0.692 | Accuracy: 0.696000 | 1.317 sec/iter
# Epoch: 08 | Batch: 002 / 011 | Total loss: 0.688 | Reg loss: 0.012 | Tree loss: 0.688 | Accuracy: 0.704500 | 1.317 sec/iter
# Epoch: 08 | Batch: 003 / 011 | Total loss: 0.688 | Reg loss: 0.012 | Tree loss: 0.688 | Accuracy: 0.651000 | 1.314 sec/iter
# Epoch: 08 | Batch: 004 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.608000 | 1.314 sec/iter
# Epoch: 08 | Batch: 005 / 011 | Total loss: 0.684 | Reg loss: 0.012 | Tree loss: 0.684 | Accuracy: 0.588000 | 1.314 sec/iter
# Epoch: 08 | Batch: 006 / 011 | Total loss: 0.687 | Reg loss: 0.012 | Tree loss: 0.687 | Accuracy: 0.574500 | 1.314 sec/iter
# Epoch: 08 | Batch: 007 / 011 | Total loss: 0.687 | Reg loss: 0.012 | Tree loss: 0.687 | Accuracy: 0.559000 | 1.315 sec/iter
# Epoch: 08 | Batch: 008 / 011 | Total loss: 0.682 | Reg loss: 0.012 | Tree loss: 0.682 | Accuracy: 0.583000 | 1.315 sec/iter
# Epoch: 08 | Batch: 009 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.561000 | 1.316 sec/iter
# Epoch: 08 | Batch: 010 / 011 | Total loss: 0.688 | Reg loss: 0.012 | Tree loss: 0.688 | Accuracy: 0.559727 | 1.311 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 09 | Batch: 000 / 011 | Total loss: 0.692 | Reg loss: 0.012 | Tree loss: 0.692 | Accuracy: 0.695000 | 1.316 sec/iter
# Epoch: 09 | Batch: 001 / 011 | Total loss: 0.692 | Reg loss: 0.012 | Tree loss: 0.692 | Accuracy: 0.688000 | 1.316 sec/iter
# Epoch: 09 | Batch: 002 / 011 | Total loss: 0.690 | Reg loss: 0.012 | Tree loss: 0.690 | Accuracy: 0.693500 | 1.316 sec/iter
# Epoch: 09 | Batch: 003 / 011 | Total loss: 0.692 | Reg loss: 0.012 | Tree loss: 0.692 | Accuracy: 0.691000 | 1.313 sec/iter
# Epoch: 09 | Batch: 004 / 011 | Total loss: 0.687 | Reg loss: 0.012 | Tree loss: 0.687 | Accuracy: 0.745000 | 1.314 sec/iter
# Epoch: 09 | Batch: 005 / 011 | Total loss: 0.683 | Reg loss: 0.012 | Tree loss: 0.683 | Accuracy: 0.715000 | 1.314 sec/iter
# Epoch: 09 | Batch: 006 / 011 | Total loss: 0.686 | Reg loss: 0.012 | Tree loss: 0.686 | Accuracy: 0.614500 | 1.314 sec/iter
# Epoch: 09 | Batch: 007 / 011 | Total loss: 0.684 | Reg loss: 0.012 | Tree loss: 0.684 | Accuracy: 0.588000 | 1.314 sec/iter
# Epoch: 09 | Batch: 008 / 011 | Total loss: 0.683 | Reg loss: 0.012 | Tree loss: 0.683 | Accuracy: 0.574500 | 1.315 sec/iter
# Epoch: 09 | Batch: 009 / 011 | Total loss: 0.684 | Reg loss: 0.012 | Tree loss: 0.684 | Accuracy: 0.562500 | 1.315 sec/iter
# Epoch: 09 | Batch: 010 / 011 | Total loss: 0.692 | Reg loss: 0.012 | Tree loss: 0.692 | Accuracy: 0.556314 | 1.311 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 10 | Batch: 000 / 011 | Total loss: 0.694 | Reg loss: 0.011 | Tree loss: 0.694 | Accuracy: 0.686000 | 1.316 sec/iter
# Epoch: 10 | Batch: 001 / 011 | Total loss: 0.692 | Reg loss: 0.011 | Tree loss: 0.692 | Accuracy: 0.703500 | 1.315 sec/iter
# Epoch: 10 | Batch: 002 / 011 | Total loss: 0.690 | Reg loss: 0.011 | Tree loss: 0.690 | Accuracy: 0.697000 | 1.315 sec/iter
# Epoch: 10 | Batch: 003 / 011 | Total loss: 0.686 | Reg loss: 0.011 | Tree loss: 0.686 | Accuracy: 0.687500 | 1.313 sec/iter
# Epoch: 10 | Batch: 004 / 011 | Total loss: 0.685 | Reg loss: 0.012 | Tree loss: 0.685 | Accuracy: 0.646000 | 1.313 sec/iter
# Epoch: 10 | Batch: 005 / 011 | Total loss: 0.681 | Reg loss: 0.012 | Tree loss: 0.681 | Accuracy: 0.623500 | 1.313 sec/iter
# Epoch: 10 | Batch: 006 / 011 | Total loss: 0.684 | Reg loss: 0.012 | Tree loss: 0.684 | Accuracy: 0.587000 | 1.314 sec/iter
# Epoch: 10 | Batch: 007 / 011 | Total loss: 0.681 | Reg loss: 0.012 | Tree loss: 0.681 | Accuracy: 0.578500 | 1.314 sec/iter
# Epoch: 10 | Batch: 008 / 011 | Total loss: 0.680 | Reg loss: 0.012 | Tree loss: 0.680 | Accuracy: 0.574000 | 1.314 sec/iter
# Epoch: 10 | Batch: 009 / 011 | Total loss: 0.677 | Reg loss: 0.012 | Tree loss: 0.677 | Accuracy: 0.580500 | 1.314 sec/iter
# Epoch: 10 | Batch: 010 / 011 | Total loss: 0.673 | Reg loss: 0.012 | Tree loss: 0.673 | Accuracy: 0.593857 | 1.311 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 11 | Batch: 000 / 011 | Total loss: 0.692 | Reg loss: 0.011 | Tree loss: 0.692 | Accuracy: 0.689000 | 1.315 sec/iter
# Epoch: 11 | Batch: 001 / 011 | Total loss: 0.689 | Reg loss: 0.011 | Tree loss: 0.689 | Accuracy: 0.718000 | 1.315 sec/iter
# Epoch: 11 | Batch: 002 / 011 | Total loss: 0.689 | Reg loss: 0.011 | Tree loss: 0.689 | Accuracy: 0.716000 | 1.315 sec/iter
# Epoch: 11 | Batch: 003 / 011 | Total loss: 0.684 | Reg loss: 0.011 | Tree loss: 0.684 | Accuracy: 0.731000 | 1.313 sec/iter
# Epoch: 11 | Batch: 004 / 011 | Total loss: 0.684 | Reg loss: 0.012 | Tree loss: 0.684 | Accuracy: 0.636500 | 1.313 sec/iter
# Epoch: 11 | Batch: 005 / 011 | Total loss: 0.679 | Reg loss: 0.012 | Tree loss: 0.679 | Accuracy: 0.589000 | 1.313 sec/iter
# Epoch: 11 | Batch: 006 / 011 | Total loss: 0.680 | Reg loss: 0.012 | Tree loss: 0.680 | Accuracy: 0.570500 | 1.313 sec/iter
# Epoch: 11 | Batch: 007 / 011 | Total loss: 0.679 | Reg loss: 0.012 | Tree loss: 0.679 | Accuracy: 0.572500 | 1.313 sec/iter
# Epoch: 11 | Batch: 008 / 011 | Total loss: 0.678 | Reg loss: 0.012 | Tree loss: 0.678 | Accuracy: 0.571000 | 1.314 sec/iter
# Epoch: 11 | Batch: 009 / 011 | Total loss: 0.674 | Reg loss: 0.012 | Tree loss: 0.674 | Accuracy: 0.571000 | 1.314 sec/iter
# Epoch: 11 | Batch: 010 / 011 | Total loss: 0.668 | Reg loss: 0.012 | Tree loss: 0.668 | Accuracy: 0.593857 | 1.311 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 12 | Batch: 000 / 011 | Total loss: 0.691 | Reg loss: 0.011 | Tree loss: 0.691 | Accuracy: 0.696500 | 1.314 sec/iter
# Epoch: 12 | Batch: 001 / 011 | Total loss: 0.687 | Reg loss: 0.011 | Tree loss: 0.687 | Accuracy: 0.714500 | 1.314 sec/iter
# Epoch: 12 | Batch: 002 / 011 | Total loss: 0.689 | Reg loss: 0.011 | Tree loss: 0.689 | Accuracy: 0.724000 | 1.314 sec/iter
# Epoch: 12 | Batch: 003 / 011 | Total loss: 0.684 | Reg loss: 0.011 | Tree loss: 0.684 | Accuracy: 0.717000 | 1.312 sec/iter
# Epoch: 12 | Batch: 004 / 011 | Total loss: 0.679 | Reg loss: 0.011 | Tree loss: 0.679 | Accuracy: 0.683500 | 1.312 sec/iter
# Epoch: 12 | Batch: 005 / 011 | Total loss: 0.679 | Reg loss: 0.012 | Tree loss: 0.679 | Accuracy: 0.593000 | 1.313 sec/iter
# Epoch: 12 | Batch: 006 / 011 | Total loss: 0.671 | Reg loss: 0.012 | Tree loss: 0.671 | Accuracy: 0.599000 | 1.313 sec/iter
# Epoch: 12 | Batch: 007 / 011 | Total loss: 0.678 | Reg loss: 0.012 | Tree loss: 0.678 | Accuracy: 0.560000 | 1.313 sec/iter
# Epoch: 12 | Batch: 008 / 011 | Total loss: 0.673 | Reg loss: 0.012 | Tree loss: 0.673 | Accuracy: 0.563000 | 1.314 sec/iter
# Epoch: 12 | Batch: 009 / 011 | Total loss: 0.669 | Reg loss: 0.012 | Tree loss: 0.669 | Accuracy: 0.570000 | 1.314 sec/iter
# Epoch: 12 | Batch: 010 / 011 | Total loss: 0.666 | Reg loss: 0.012 | Tree loss: 0.666 | Accuracy: 0.569966 | 1.311 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 13 | Batch: 000 / 011 | Total loss: 0.687 | Reg loss: 0.011 | Tree loss: 0.687 | Accuracy: 0.707500 | 1.314 sec/iter
# Epoch: 13 | Batch: 001 / 011 | Total loss: 0.687 | Reg loss: 0.011 | Tree loss: 0.687 | Accuracy: 0.711000 | 1.314 sec/iter
# Epoch: 13 | Batch: 002 / 011 | Total loss: 0.685 | Reg loss: 0.011 | Tree loss: 0.685 | Accuracy: 0.713000 | 1.314 sec/iter
# Epoch: 13 | Batch: 003 / 011 | Total loss: 0.679 | Reg loss: 0.011 | Tree loss: 0.679 | Accuracy: 0.715500 | 1.312 sec/iter
# Epoch: 13 | Batch: 004 / 011 | Total loss: 0.678 | Reg loss: 0.011 | Tree loss: 0.678 | Accuracy: 0.636000 | 1.312 sec/iter
# Epoch: 13 | Batch: 005 / 011 | Total loss: 0.678 | Reg loss: 0.012 | Tree loss: 0.678 | Accuracy: 0.576000 | 1.312 sec/iter
# Epoch: 13 | Batch: 006 / 011 | Total loss: 0.669 | Reg loss: 0.012 | Tree loss: 0.669 | Accuracy: 0.588500 | 1.313 sec/iter
# Epoch: 13 | Batch: 007 / 011 | Total loss: 0.666 | Reg loss: 0.012 | Tree loss: 0.666 | Accuracy: 0.581500 | 1.313 sec/iter
# Epoch: 13 | Batch: 008 / 011 | Total loss: 0.664 | Reg loss: 0.012 | Tree loss: 0.664 | Accuracy: 0.583000 | 1.313 sec/iter
# Epoch: 13 | Batch: 009 / 011 | Total loss: 0.661 | Reg loss: 0.012 | Tree loss: 0.661 | Accuracy: 0.594500 | 1.313 sec/iter
# Epoch: 13 | Batch: 010 / 011 | Total loss: 0.664 | Reg loss: 0.012 | Tree loss: 0.664 | Accuracy: 0.607509 | 1.31 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 14 | Batch: 000 / 011 | Total loss: 0.687 | Reg loss: 0.011 | Tree loss: 0.687 | Accuracy: 0.727000 | 1.314 sec/iter
# Epoch: 14 | Batch: 001 / 011 | Total loss: 0.684 | Reg loss: 0.011 | Tree loss: 0.684 | Accuracy: 0.725000 | 1.314 sec/iter
# Epoch: 14 | Batch: 002 / 011 | Total loss: 0.680 | Reg loss: 0.011 | Tree loss: 0.680 | Accuracy: 0.729500 | 1.314 sec/iter
# Epoch: 14 | Batch: 003 / 011 | Total loss: 0.675 | Reg loss: 0.011 | Tree loss: 0.675 | Accuracy: 0.686500 | 1.312 sec/iter
# Epoch: 14 | Batch: 004 / 011 | Total loss: 0.672 | Reg loss: 0.011 | Tree loss: 0.672 | Accuracy: 0.633500 | 1.312 sec/iter
# Epoch: 14 | Batch: 005 / 011 | Total loss: 0.662 | Reg loss: 0.012 | Tree loss: 0.662 | Accuracy: 0.635500 | 1.312 sec/iter
# Epoch: 14 | Batch: 006 / 011 | Total loss: 0.662 | Reg loss: 0.012 | Tree loss: 0.662 | Accuracy: 0.596000 | 1.312 sec/iter
# Epoch: 14 | Batch: 007 / 011 | Total loss: 0.662 | Reg loss: 0.012 | Tree loss: 0.662 | Accuracy: 0.573500 | 1.312 sec/iter
# Epoch: 14 | Batch: 008 / 011 | Total loss: 0.669 | Reg loss: 0.012 | Tree loss: 0.669 | Accuracy: 0.548500 | 1.313 sec/iter
# Epoch: 14 | Batch: 009 / 011 | Total loss: 0.656 | Reg loss: 0.012 | Tree loss: 0.656 | Accuracy: 0.594500 | 1.313 sec/iter
# Epoch: 14 | Batch: 010 / 011 | Total loss: 0.674 | Reg loss: 0.012 | Tree loss: 0.674 | Accuracy: 0.587031 | 1.31 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 15 | Batch: 000 / 011 | Total loss: 0.683 | Reg loss: 0.011 | Tree loss: 0.683 | Accuracy: 0.716500 | 1.313 sec/iter
# Epoch: 15 | Batch: 001 / 011 | Total loss: 0.680 | Reg loss: 0.011 | Tree loss: 0.680 | Accuracy: 0.707000 | 1.313 sec/iter
# Epoch: 15 | Batch: 002 / 011 | Total loss: 0.675 | Reg loss: 0.011 | Tree loss: 0.675 | Accuracy: 0.703500 | 1.313 sec/iter
# Epoch: 15 | Batch: 003 / 011 | Total loss: 0.671 | Reg loss: 0.011 | Tree loss: 0.671 | Accuracy: 0.661000 | 1.311 sec/iter
# Epoch: 15 | Batch: 004 / 011 | Total loss: 0.667 | Reg loss: 0.011 | Tree loss: 0.667 | Accuracy: 0.638000 | 1.311 sec/iter
# Epoch: 15 | Batch: 005 / 011 | Total loss: 0.656 | Reg loss: 0.012 | Tree loss: 0.656 | Accuracy: 0.656500 | 1.312 sec/iter
# Epoch: 15 | Batch: 006 / 011 | Total loss: 0.668 | Reg loss: 0.012 | Tree loss: 0.668 | Accuracy: 0.576500 | 1.312 sec/iter
# Epoch: 15 | Batch: 007 / 011 | Total loss: 0.659 | Reg loss: 0.012 | Tree loss: 0.659 | Accuracy: 0.585000 | 1.312 sec/iter
# Epoch: 15 | Batch: 008 / 011 | Total loss: 0.648 | Reg loss: 0.012 | Tree loss: 0.648 | Accuracy: 0.630000 | 1.312 sec/iter
# Epoch: 15 | Batch: 009 / 011 | Total loss: 0.653 | Reg loss: 0.012 | Tree loss: 0.653 | Accuracy: 0.628000 | 1.312 sec/iter
# Epoch: 15 | Batch: 010 / 011 | Total loss: 0.658 | Reg loss: 0.012 | Tree loss: 0.658 | Accuracy: 0.645051 | 1.31 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 16 | Batch: 000 / 011 | Total loss: 0.680 | Reg loss: 0.011 | Tree loss: 0.680 | Accuracy: 0.706500 | 1.313 sec/iter
# Epoch: 16 | Batch: 001 / 011 | Total loss: 0.674 | Reg loss: 0.011 | Tree loss: 0.674 | Accuracy: 0.699500 | 1.313 sec/iter
# Epoch: 16 | Batch: 002 / 011 | Total loss: 0.669 | Reg loss: 0.011 | Tree loss: 0.669 | Accuracy: 0.652000 | 1.313 sec/iter
# Epoch: 16 | Batch: 003 / 011 | Total loss: 0.663 | Reg loss: 0.011 | Tree loss: 0.663 | Accuracy: 0.644000 | 1.311 sec/iter
# Epoch: 16 | Batch: 004 / 011 | Total loss: 0.662 | Reg loss: 0.012 | Tree loss: 0.662 | Accuracy: 0.616000 | 1.311 sec/iter
# Epoch: 16 | Batch: 005 / 011 | Total loss: 0.660 | Reg loss: 0.012 | Tree loss: 0.660 | Accuracy: 0.600500 | 1.311 sec/iter
# Epoch: 16 | Batch: 006 / 011 | Total loss: 0.656 | Reg loss: 0.012 | Tree loss: 0.656 | Accuracy: 0.611500 | 1.311 sec/iter
# Epoch: 16 | Batch: 007 / 011 | Total loss: 0.655 | Reg loss: 0.012 | Tree loss: 0.655 | Accuracy: 0.619500 | 1.312 sec/iter
# Epoch: 16 | Batch: 008 / 011 | Total loss: 0.642 | Reg loss: 0.012 | Tree loss: 0.642 | Accuracy: 0.672000 | 1.312 sec/iter
# Epoch: 16 | Batch: 009 / 011 | Total loss: 0.645 | Reg loss: 0.012 | Tree loss: 0.645 | Accuracy: 0.672500 | 1.312 sec/iter
# Epoch: 16 | Batch: 010 / 011 | Total loss: 0.651 | Reg loss: 0.012 | Tree loss: 0.651 | Accuracy: 0.658703 | 1.31 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 17 | Batch: 000 / 011 | Total loss: 0.675 | Reg loss: 0.011 | Tree loss: 0.675 | Accuracy: 0.691500 | 1.312 sec/iter
# Epoch: 17 | Batch: 001 / 011 | Total loss: 0.670 | Reg loss: 0.011 | Tree loss: 0.670 | Accuracy: 0.695500 | 1.312 sec/iter
# Epoch: 17 | Batch: 002 / 011 | Total loss: 0.664 | Reg loss: 0.012 | Tree loss: 0.664 | Accuracy: 0.664000 | 1.312 sec/iter
# Epoch: 17 | Batch: 003 / 011 | Total loss: 0.663 | Reg loss: 0.012 | Tree loss: 0.663 | Accuracy: 0.639000 | 1.311 sec/iter
# Epoch: 17 | Batch: 004 / 011 | Total loss: 0.650 | Reg loss: 0.012 | Tree loss: 0.650 | Accuracy: 0.633000 | 1.311 sec/iter
# Epoch: 17 | Batch: 005 / 011 | Total loss: 0.657 | Reg loss: 0.012 | Tree loss: 0.657 | Accuracy: 0.603500 | 1.311 sec/iter
# Epoch: 17 | Batch: 006 / 011 | Total loss: 0.650 | Reg loss: 0.012 | Tree loss: 0.650 | Accuracy: 0.632500 | 1.311 sec/iter
# Epoch: 17 | Batch: 007 / 011 | Total loss: 0.644 | Reg loss: 0.012 | Tree loss: 0.644 | Accuracy: 0.631500 | 1.312 sec/iter
# Epoch: 17 | Batch: 008 / 011 | Total loss: 0.641 | Reg loss: 0.012 | Tree loss: 0.641 | Accuracy: 0.676000 | 1.312 sec/iter
# Epoch: 17 | Batch: 009 / 011 | Total loss: 0.640 | Reg loss: 0.012 | Tree loss: 0.640 | Accuracy: 0.677500 | 1.312 sec/iter
# Epoch: 17 | Batch: 010 / 011 | Total loss: 0.628 | Reg loss: 0.012 | Tree loss: 0.628 | Accuracy: 0.713311 | 1.31 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 18 | Batch: 000 / 011 | Total loss: 0.665 | Reg loss: 0.012 | Tree loss: 0.665 | Accuracy: 0.711500 | 1.312 sec/iter
# Epoch: 18 | Batch: 001 / 011 | Total loss: 0.660 | Reg loss: 0.012 | Tree loss: 0.660 | Accuracy: 0.690500 | 1.312 sec/iter
# Epoch: 18 | Batch: 002 / 011 | Total loss: 0.661 | Reg loss: 0.012 | Tree loss: 0.661 | Accuracy: 0.641500 | 1.312 sec/iter
# Epoch: 18 | Batch: 003 / 011 | Total loss: 0.655 | Reg loss: 0.012 | Tree loss: 0.655 | Accuracy: 0.630000 | 1.311 sec/iter
# Epoch: 18 | Batch: 004 / 011 | Total loss: 0.661 | Reg loss: 0.012 | Tree loss: 0.661 | Accuracy: 0.592500 | 1.311 sec/iter
# Epoch: 18 | Batch: 005 / 011 | Total loss: 0.648 | Reg loss: 0.012 | Tree loss: 0.648 | Accuracy: 0.632000 | 1.311 sec/iter
# Epoch: 18 | Batch: 006 / 011 | Total loss: 0.645 | Reg loss: 0.012 | Tree loss: 0.645 | Accuracy: 0.642500 | 1.311 sec/iter
# Epoch: 18 | Batch: 007 / 011 | Total loss: 0.645 | Reg loss: 0.012 | Tree loss: 0.645 | Accuracy: 0.675000 | 1.311 sec/iter
# Epoch: 18 | Batch: 008 / 011 | Total loss: 0.640 | Reg loss: 0.012 | Tree loss: 0.640 | Accuracy: 0.690500 | 1.312 sec/iter
# Epoch: 18 | Batch: 009 / 011 | Total loss: 0.636 | Reg loss: 0.012 | Tree loss: 0.636 | Accuracy: 0.698000 | 1.312 sec/iter
# Epoch: 18 | Batch: 010 / 011 | Total loss: 0.610 | Reg loss: 0.012 | Tree loss: 0.610 | Accuracy: 0.771331 | 1.31 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 19 | Batch: 000 / 011 | Total loss: 0.666 | Reg loss: 0.012 | Tree loss: 0.666 | Accuracy: 0.688000 | 1.312 sec/iter
# Epoch: 19 | Batch: 001 / 011 | Total loss: 0.657 | Reg loss: 0.012 | Tree loss: 0.657 | Accuracy: 0.643500 | 1.312 sec/iter
# Epoch: 19 | Batch: 002 / 011 | Total loss: 0.655 | Reg loss: 0.012 | Tree loss: 0.655 | Accuracy: 0.599500 | 1.312 sec/iter
# Epoch: 19 | Batch: 003 / 011 | Total loss: 0.663 | Reg loss: 0.012 | Tree loss: 0.663 | Accuracy: 0.573500 | 1.311 sec/iter
# Epoch: 19 | Batch: 004 / 011 | Total loss: 0.664 | Reg loss: 0.012 | Tree loss: 0.664 | Accuracy: 0.562500 | 1.311 sec/iter
# Epoch: 19 | Batch: 005 / 011 | Total loss: 0.653 | Reg loss: 0.012 | Tree loss: 0.653 | Accuracy: 0.588500 | 1.311 sec/iter
# Epoch: 19 | Batch: 006 / 011 | Total loss: 0.640 | Reg loss: 0.012 | Tree loss: 0.640 | Accuracy: 0.652000 | 1.311 sec/iter
# Epoch: 19 | Batch: 007 / 011 | Total loss: 0.640 | Reg loss: 0.012 | Tree loss: 0.640 | Accuracy: 0.680500 | 1.311 sec/iter
# Epoch: 19 | Batch: 008 / 011 | Total loss: 0.641 | Reg loss: 0.012 | Tree loss: 0.641 | Accuracy: 0.701000 | 1.311 sec/iter
# Epoch: 19 | Batch: 009 / 011 | Total loss: 0.641 | Reg loss: 0.012 | Tree loss: 0.641 | Accuracy: 0.724500 | 1.312 sec/iter
# Epoch: 19 | Batch: 010 / 011 | Total loss: 0.638 | Reg loss: 0.013 | Tree loss: 0.638 | Accuracy: 0.764505 | 1.31 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 20 | Batch: 000 / 011 | Total loss: 0.663 | Reg loss: 0.012 | Tree loss: 0.663 | Accuracy: 0.692000 | 1.312 sec/iter
# Epoch: 20 | Batch: 001 / 011 | Total loss: 0.658 | Reg loss: 0.012 | Tree loss: 0.658 | Accuracy: 0.653500 | 1.312 sec/iter
# Epoch: 20 | Batch: 002 / 011 | Total loss: 0.650 | Reg loss: 0.012 | Tree loss: 0.650 | Accuracy: 0.636000 | 1.312 sec/iter
# Epoch: 20 | Batch: 003 / 011 | Total loss: 0.645 | Reg loss: 0.012 | Tree loss: 0.645 | Accuracy: 0.618500 | 1.31 sec/iter
# Epoch: 20 | Batch: 004 / 011 | Total loss: 0.649 | Reg loss: 0.012 | Tree loss: 0.649 | Accuracy: 0.611500 | 1.31 sec/iter
# Epoch: 20 | Batch: 005 / 011 | Total loss: 0.652 | Reg loss: 0.012 | Tree loss: 0.652 | Accuracy: 0.610500 | 1.311 sec/iter
# Epoch: 20 | Batch: 006 / 011 | Total loss: 0.635 | Reg loss: 0.012 | Tree loss: 0.635 | Accuracy: 0.655000 | 1.311 sec/iter
# Epoch: 20 | Batch: 007 / 011 | Total loss: 0.628 | Reg loss: 0.012 | Tree loss: 0.628 | Accuracy: 0.699500 | 1.311 sec/iter
# Epoch: 20 | Batch: 008 / 011 | Total loss: 0.628 | Reg loss: 0.012 | Tree loss: 0.628 | Accuracy: 0.699000 | 1.311 sec/iter
# Epoch: 20 | Batch: 009 / 011 | Total loss: 0.633 | Reg loss: 0.013 | Tree loss: 0.633 | Accuracy: 0.710500 | 1.311 sec/iter
# Epoch: 20 | Batch: 010 / 011 | Total loss: 0.627 | Reg loss: 0.013 | Tree loss: 0.627 | Accuracy: 0.723549 | 1.309 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 21 | Batch: 000 / 011 | Total loss: 0.658 | Reg loss: 0.012 | Tree loss: 0.658 | Accuracy: 0.702500 | 1.312 sec/iter
# Epoch: 21 | Batch: 001 / 011 | Total loss: 0.650 | Reg loss: 0.012 | Tree loss: 0.650 | Accuracy: 0.670000 | 1.311 sec/iter
# Epoch: 21 | Batch: 002 / 011 | Total loss: 0.649 | Reg loss: 0.012 | Tree loss: 0.649 | Accuracy: 0.640000 | 1.311 sec/iter
# Epoch: 21 | Batch: 003 / 011 | Total loss: 0.644 | Reg loss: 0.012 | Tree loss: 0.644 | Accuracy: 0.632000 | 1.31 sec/iter
# Epoch: 21 | Batch: 004 / 011 | Total loss: 0.638 | Reg loss: 0.012 | Tree loss: 0.638 | Accuracy: 0.632000 | 1.31 sec/iter
# Epoch: 21 | Batch: 005 / 011 | Total loss: 0.643 | Reg loss: 0.012 | Tree loss: 0.643 | Accuracy: 0.627500 | 1.31 sec/iter
# Epoch: 21 | Batch: 006 / 011 | Total loss: 0.631 | Reg loss: 0.012 | Tree loss: 0.631 | Accuracy: 0.639000 | 1.311 sec/iter
# Epoch: 21 | Batch: 007 / 011 | Total loss: 0.631 | Reg loss: 0.013 | Tree loss: 0.631 | Accuracy: 0.677500 | 1.311 sec/iter
# Epoch: 21 | Batch: 008 / 011 | Total loss: 0.626 | Reg loss: 0.013 | Tree loss: 0.626 | Accuracy: 0.686500 | 1.311 sec/iter
# Epoch: 21 | Batch: 009 / 011 | Total loss: 0.622 | Reg loss: 0.013 | Tree loss: 0.622 | Accuracy: 0.714500 | 1.311 sec/iter
# Epoch: 21 | Batch: 010 / 011 | Total loss: 0.622 | Reg loss: 0.013 | Tree loss: 0.622 | Accuracy: 0.699659 | 1.309 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 22 | Batch: 000 / 011 | Total loss: 0.647 | Reg loss: 0.012 | Tree loss: 0.647 | Accuracy: 0.706500 | 1.311 sec/iter
# Epoch: 22 | Batch: 001 / 011 | Total loss: 0.649 | Reg loss: 0.012 | Tree loss: 0.649 | Accuracy: 0.683500 | 1.311 sec/iter
# Epoch: 22 | Batch: 002 / 011 | Total loss: 0.640 | Reg loss: 0.012 | Tree loss: 0.640 | Accuracy: 0.690000 | 1.311 sec/iter
# Epoch: 22 | Batch: 003 / 011 | Total loss: 0.644 | Reg loss: 0.012 | Tree loss: 0.644 | Accuracy: 0.672000 | 1.31 sec/iter
# Epoch: 22 | Batch: 004 / 011 | Total loss: 0.632 | Reg loss: 0.013 | Tree loss: 0.632 | Accuracy: 0.672500 | 1.31 sec/iter
# Epoch: 22 | Batch: 005 / 011 | Total loss: 0.633 | Reg loss: 0.013 | Tree loss: 0.633 | Accuracy: 0.669000 | 1.31 sec/iter
# Epoch: 22 | Batch: 006 / 011 | Total loss: 0.616 | Reg loss: 0.013 | Tree loss: 0.616 | Accuracy: 0.705500 | 1.31 sec/iter
# Epoch: 22 | Batch: 007 / 011 | Total loss: 0.617 | Reg loss: 0.013 | Tree loss: 0.617 | Accuracy: 0.695000 | 1.311 sec/iter
# Epoch: 22 | Batch: 008 / 011 | Total loss: 0.616 | Reg loss: 0.013 | Tree loss: 0.616 | Accuracy: 0.699500 | 1.311 sec/iter
# Epoch: 22 | Batch: 009 / 011 | Total loss: 0.618 | Reg loss: 0.013 | Tree loss: 0.618 | Accuracy: 0.684500 | 1.311 sec/iter
# Epoch: 22 | Batch: 010 / 011 | Total loss: 0.616 | Reg loss: 0.013 | Tree loss: 0.616 | Accuracy: 0.703072 | 1.309 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 23 | Batch: 000 / 011 | Total loss: 0.649 | Reg loss: 0.013 | Tree loss: 0.649 | Accuracy: 0.691000 | 1.311 sec/iter
# Epoch: 23 | Batch: 001 / 011 | Total loss: 0.651 | Reg loss: 0.013 | Tree loss: 0.651 | Accuracy: 0.650000 | 1.311 sec/iter
# Epoch: 23 | Batch: 002 / 011 | Total loss: 0.632 | Reg loss: 0.013 | Tree loss: 0.632 | Accuracy: 0.665500 | 1.311 sec/iter
# Epoch: 23 | Batch: 003 / 011 | Total loss: 0.634 | Reg loss: 0.013 | Tree loss: 0.634 | Accuracy: 0.648000 | 1.31 sec/iter
# Epoch: 23 | Batch: 004 / 011 | Total loss: 0.634 | Reg loss: 0.013 | Tree loss: 0.634 | Accuracy: 0.632500 | 1.31 sec/iter
# Epoch: 23 | Batch: 005 / 011 | Total loss: 0.615 | Reg loss: 0.013 | Tree loss: 0.615 | Accuracy: 0.687500 | 1.31 sec/iter
# Epoch: 23 | Batch: 006 / 011 | Total loss: 0.618 | Reg loss: 0.013 | Tree loss: 0.618 | Accuracy: 0.693000 | 1.31 sec/iter
# Epoch: 23 | Batch: 007 / 011 | Total loss: 0.612 | Reg loss: 0.013 | Tree loss: 0.612 | Accuracy: 0.703000 | 1.31 sec/iter
# Epoch: 23 | Batch: 008 / 011 | Total loss: 0.615 | Reg loss: 0.013 | Tree loss: 0.615 | Accuracy: 0.734500 | 1.311 sec/iter
# Epoch: 23 | Batch: 009 / 011 | Total loss: 0.611 | Reg loss: 0.013 | Tree loss: 0.611 | Accuracy: 0.738500 | 1.311 sec/iter
# Epoch: 23 | Batch: 010 / 011 | Total loss: 0.593 | Reg loss: 0.014 | Tree loss: 0.593 | Accuracy: 0.788396 | 1.309 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 24 | Batch: 000 / 011 | Total loss: 0.635 | Reg loss: 0.013 | Tree loss: 0.635 | Accuracy: 0.721500 | 1.311 sec/iter
# Epoch: 24 | Batch: 001 / 011 | Total loss: 0.631 | Reg loss: 0.013 | Tree loss: 0.631 | Accuracy: 0.694000 | 1.311 sec/iter
# Epoch: 24 | Batch: 002 / 011 | Total loss: 0.628 | Reg loss: 0.013 | Tree loss: 0.628 | Accuracy: 0.662000 | 1.311 sec/iter
# Epoch: 24 | Batch: 003 / 011 | Total loss: 0.631 | Reg loss: 0.013 | Tree loss: 0.631 | Accuracy: 0.645000 | 1.31 sec/iter
# Epoch: 24 | Batch: 004 / 011 | Total loss: 0.639 | Reg loss: 0.013 | Tree loss: 0.639 | Accuracy: 0.622500 | 1.31 sec/iter
# Epoch: 24 | Batch: 005 / 011 | Total loss: 0.615 | Reg loss: 0.013 | Tree loss: 0.615 | Accuracy: 0.676000 | 1.31 sec/iter
# Epoch: 24 | Batch: 006 / 011 | Total loss: 0.616 | Reg loss: 0.013 | Tree loss: 0.616 | Accuracy: 0.688500 | 1.31 sec/iter
# Epoch: 24 | Batch: 007 / 011 | Total loss: 0.607 | Reg loss: 0.013 | Tree loss: 0.607 | Accuracy: 0.749000 | 1.31 sec/iter
# Epoch: 24 | Batch: 008 / 011 | Total loss: 0.611 | Reg loss: 0.014 | Tree loss: 0.611 | Accuracy: 0.738000 | 1.31 sec/iter
# Epoch: 24 | Batch: 009 / 011 | Total loss: 0.601 | Reg loss: 0.014 | Tree loss: 0.601 | Accuracy: 0.748500 | 1.311 sec/iter
# Epoch: 24 | Batch: 010 / 011 | Total loss: 0.587 | Reg loss: 0.014 | Tree loss: 0.587 | Accuracy: 0.784983 | 1.309 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 25 | Batch: 000 / 011 | Total loss: 0.640 | Reg loss: 0.013 | Tree loss: 0.640 | Accuracy: 0.725000 | 1.311 sec/iter
# Epoch: 25 | Batch: 001 / 011 | Total loss: 0.629 | Reg loss: 0.013 | Tree loss: 0.629 | Accuracy: 0.696000 | 1.311 sec/iter
# Epoch: 25 | Batch: 002 / 011 | Total loss: 0.628 | Reg loss: 0.013 | Tree loss: 0.628 | Accuracy: 0.648500 | 1.311 sec/iter
# Epoch: 25 | Batch: 003 / 011 | Total loss: 0.619 | Reg loss: 0.013 | Tree loss: 0.619 | Accuracy: 0.660500 | 1.31 sec/iter
# Epoch: 25 | Batch: 004 / 011 | Total loss: 0.617 | Reg loss: 0.013 | Tree loss: 0.617 | Accuracy: 0.647000 | 1.31 sec/iter
# Epoch: 25 | Batch: 005 / 011 | Total loss: 0.612 | Reg loss: 0.013 | Tree loss: 0.612 | Accuracy: 0.668000 | 1.31 sec/iter
# Epoch: 25 | Batch: 006 / 011 | Total loss: 0.602 | Reg loss: 0.014 | Tree loss: 0.602 | Accuracy: 0.712000 | 1.31 sec/iter
# Epoch: 25 | Batch: 007 / 011 | Total loss: 0.605 | Reg loss: 0.014 | Tree loss: 0.605 | Accuracy: 0.728500 | 1.31 sec/iter
# Epoch: 25 | Batch: 008 / 011 | Total loss: 0.596 | Reg loss: 0.014 | Tree loss: 0.596 | Accuracy: 0.761500 | 1.31 sec/iter
# Epoch: 25 | Batch: 009 / 011 | Total loss: 0.589 | Reg loss: 0.014 | Tree loss: 0.589 | Accuracy: 0.765500 | 1.31 sec/iter
# Epoch: 25 | Batch: 010 / 011 | Total loss: 0.599 | Reg loss: 0.014 | Tree loss: 0.599 | Accuracy: 0.740614 | 1.309 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 26 | Batch: 000 / 011 | Total loss: 0.635 | Reg loss: 0.013 | Tree loss: 0.635 | Accuracy: 0.723500 | 1.311 sec/iter
# Epoch: 26 | Batch: 001 / 011 | Total loss: 0.625 | Reg loss: 0.013 | Tree loss: 0.625 | Accuracy: 0.704000 | 1.311 sec/iter
# Epoch: 26 | Batch: 002 / 011 | Total loss: 0.622 | Reg loss: 0.014 | Tree loss: 0.622 | Accuracy: 0.668000 | 1.311 sec/iter
# Epoch: 26 | Batch: 003 / 011 | Total loss: 0.615 | Reg loss: 0.014 | Tree loss: 0.615 | Accuracy: 0.654000 | 1.31 sec/iter
# Epoch: 26 | Batch: 004 / 011 | Total loss: 0.621 | Reg loss: 0.014 | Tree loss: 0.621 | Accuracy: 0.637500 | 1.31 sec/iter
# Epoch: 26 | Batch: 005 / 011 | Total loss: 0.606 | Reg loss: 0.014 | Tree loss: 0.606 | Accuracy: 0.678500 | 1.31 sec/iter
# Epoch: 26 | Batch: 006 / 011 | Total loss: 0.592 | Reg loss: 0.014 | Tree loss: 0.592 | Accuracy: 0.728000 | 1.31 sec/iter
# Epoch: 26 | Batch: 007 / 011 | Total loss: 0.593 | Reg loss: 0.014 | Tree loss: 0.593 | Accuracy: 0.754500 | 1.31 sec/iter
# Epoch: 26 | Batch: 008 / 011 | Total loss: 0.594 | Reg loss: 0.014 | Tree loss: 0.594 | Accuracy: 0.750000 | 1.31 sec/iter
# Epoch: 26 | Batch: 009 / 011 | Total loss: 0.582 | Reg loss: 0.014 | Tree loss: 0.582 | Accuracy: 0.777500 | 1.31 sec/iter
# Epoch: 26 | Batch: 010 / 011 | Total loss: 0.581 | Reg loss: 0.015 | Tree loss: 0.581 | Accuracy: 0.744027 | 1.309 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 27 | Batch: 000 / 011 | Total loss: 0.628 | Reg loss: 0.014 | Tree loss: 0.628 | Accuracy: 0.739500 | 1.311 sec/iter
# Epoch: 27 | Batch: 001 / 011 | Total loss: 0.625 | Reg loss: 0.014 | Tree loss: 0.625 | Accuracy: 0.719000 | 1.311 sec/iter
# Epoch: 27 | Batch: 002 / 011 | Total loss: 0.626 | Reg loss: 0.014 | Tree loss: 0.626 | Accuracy: 0.637000 | 1.311 sec/iter
# Epoch: 27 | Batch: 003 / 011 | Total loss: 0.622 | Reg loss: 0.014 | Tree loss: 0.622 | Accuracy: 0.647000 | 1.31 sec/iter
# Epoch: 27 | Batch: 004 / 011 | Total loss: 0.612 | Reg loss: 0.014 | Tree loss: 0.612 | Accuracy: 0.661500 | 1.31 sec/iter
# Epoch: 27 | Batch: 005 / 011 | Total loss: 0.594 | Reg loss: 0.014 | Tree loss: 0.594 | Accuracy: 0.697000 | 1.31 sec/iter
# Epoch: 27 | Batch: 006 / 011 | Total loss: 0.587 | Reg loss: 0.014 | Tree loss: 0.587 | Accuracy: 0.722500 | 1.31 sec/iter
# Epoch: 27 | Batch: 007 / 011 | Total loss: 0.591 | Reg loss: 0.014 | Tree loss: 0.591 | Accuracy: 0.745000 | 1.31 sec/iter
# Epoch: 27 | Batch: 008 / 011 | Total loss: 0.580 | Reg loss: 0.015 | Tree loss: 0.580 | Accuracy: 0.766500 | 1.31 sec/iter
# Epoch: 27 | Batch: 009 / 011 | Total loss: 0.577 | Reg loss: 0.015 | Tree loss: 0.577 | Accuracy: 0.763500 | 1.31 sec/iter
# Epoch: 27 | Batch: 010 / 011 | Total loss: 0.565 | Reg loss: 0.015 | Tree loss: 0.565 | Accuracy: 0.815700 | 1.309 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 28 | Batch: 000 / 011 | Total loss: 0.630 | Reg loss: 0.014 | Tree loss: 0.630 | Accuracy: 0.729000 | 1.311 sec/iter
# Epoch: 28 | Batch: 001 / 011 | Total loss: 0.616 | Reg loss: 0.014 | Tree loss: 0.616 | Accuracy: 0.711000 | 1.311 sec/iter
# Epoch: 28 | Batch: 002 / 011 | Total loss: 0.619 | Reg loss: 0.014 | Tree loss: 0.619 | Accuracy: 0.657500 | 1.311 sec/iter
# Epoch: 28 | Batch: 003 / 011 | Total loss: 0.603 | Reg loss: 0.014 | Tree loss: 0.603 | Accuracy: 0.668000 | 1.31 sec/iter
# Epoch: 28 | Batch: 004 / 011 | Total loss: 0.610 | Reg loss: 0.014 | Tree loss: 0.610 | Accuracy: 0.645500 | 1.31 sec/iter
# Epoch: 28 | Batch: 005 / 011 | Total loss: 0.592 | Reg loss: 0.014 | Tree loss: 0.592 | Accuracy: 0.703500 | 1.31 sec/iter
# Epoch: 28 | Batch: 006 / 011 | Total loss: 0.580 | Reg loss: 0.015 | Tree loss: 0.580 | Accuracy: 0.737000 | 1.31 sec/iter
# Epoch: 28 | Batch: 007 / 011 | Total loss: 0.582 | Reg loss: 0.015 | Tree loss: 0.582 | Accuracy: 0.761500 | 1.31 sec/iter
# Epoch: 28 | Batch: 008 / 011 | Total loss: 0.582 | Reg loss: 0.015 | Tree loss: 0.582 | Accuracy: 0.753000 | 1.31 sec/iter
# Epoch: 28 | Batch: 009 / 011 | Total loss: 0.578 | Reg loss: 0.015 | Tree loss: 0.578 | Accuracy: 0.774000 | 1.31 sec/iter
# Epoch: 28 | Batch: 010 / 011 | Total loss: 0.571 | Reg loss: 0.015 | Tree loss: 0.571 | Accuracy: 0.832765 | 1.309 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# ...
# Epoch: 490 | Batch: 003 / 011 | Total loss: 0.405 | Reg loss: 0.027 | Tree loss: 0.405 | Accuracy: 0.824000 | 1.0 sec/iter
# Epoch: 490 | Batch: 004 / 011 | Total loss: 0.378 | Reg loss: 0.027 | Tree loss: 0.378 | Accuracy: 0.853500 | 1.0 sec/iter
# Epoch: 490 | Batch: 005 / 011 | Total loss: 0.378 | Reg loss: 0.027 | Tree loss: 0.378 | Accuracy: 0.857000 | 1.0 sec/iter
# Epoch: 490 | Batch: 006 / 011 | Total loss: 0.394 | Reg loss: 0.027 | Tree loss: 0.394 | Accuracy: 0.816000 | 1.0 sec/iter
# Epoch: 490 | Batch: 007 / 011 | Total loss: 0.404 | Reg loss: 0.027 | Tree loss: 0.404 | Accuracy: 0.812500 | 1.0 sec/iter
# Epoch: 490 | Batch: 008 / 011 | Total loss: 0.389 | Reg loss: 0.027 | Tree loss: 0.389 | Accuracy: 0.829000 | 1.0 sec/iter
# Epoch: 490 | Batch: 009 / 011 | Total loss: 0.375 | Reg loss: 0.027 | Tree loss: 0.375 | Accuracy: 0.846000 | 1.0 sec/iter
# Epoch: 490 | Batch: 010 / 011 | Total loss: 0.372 | Reg loss: 0.027 | Tree loss: 0.372 | Accuracy: 0.883959 | 1.0 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 491 | Batch: 000 / 011 | Total loss: 0.444 | Reg loss: 0.027 | Tree loss: 0.444 | Accuracy: 0.803000 | 1.0 sec/iter
# Epoch: 491 | Batch: 001 / 011 | Total loss: 0.428 | Reg loss: 0.027 | Tree loss: 0.428 | Accuracy: 0.825500 | 1.0 sec/iter
# Epoch: 491 | Batch: 002 / 011 | Total loss: 0.403 | Reg loss: 0.027 | Tree loss: 0.403 | Accuracy: 0.829500 | 1.0 sec/iter
# Epoch: 491 | Batch: 003 / 011 | Total loss: 0.384 | Reg loss: 0.027 | Tree loss: 0.384 | Accuracy: 0.851000 | 1.0 sec/iter
# Epoch: 491 | Batch: 004 / 011 | Total loss: 0.382 | Reg loss: 0.027 | Tree loss: 0.382 | Accuracy: 0.856000 | 1.0 sec/iter
# Epoch: 491 | Batch: 005 / 011 | Total loss: 0.377 | Reg loss: 0.027 | Tree loss: 0.377 | Accuracy: 0.855000 | 1.0 sec/iter
# Epoch: 491 | Batch: 006 / 011 | Total loss: 0.393 | Reg loss: 0.027 | Tree loss: 0.393 | Accuracy: 0.829000 | 1.0 sec/iter
# Epoch: 491 | Batch: 007 / 011 | Total loss: 0.400 | Reg loss: 0.027 | Tree loss: 0.400 | Accuracy: 0.808000 | 1.0 sec/iter
# Epoch: 491 | Batch: 008 / 011 | Total loss: 0.395 | Reg loss: 0.027 | Tree loss: 0.395 | Accuracy: 0.818000 | 1.0 sec/iter
# Epoch: 491 | Batch: 009 / 011 | Total loss: 0.377 | Reg loss: 0.027 | Tree loss: 0.377 | Accuracy: 0.847000 | 1.0 sec/iter
# Epoch: 491 | Batch: 010 / 011 | Total loss: 0.361 | Reg loss: 0.027 | Tree loss: 0.361 | Accuracy: 0.904437 | 0.999 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 492 | Batch: 000 / 011 | Total loss: 0.407 | Reg loss: 0.027 | Tree loss: 0.407 | Accuracy: 0.834000 | 1.0 sec/iter
# Epoch: 492 | Batch: 001 / 011 | Total loss: 0.442 | Reg loss: 0.027 | Tree loss: 0.442 | Accuracy: 0.810500 | 0.999 sec/iter
# Epoch: 492 | Batch: 002 / 011 | Total loss: 0.406 | Reg loss: 0.027 | Tree loss: 0.406 | Accuracy: 0.830500 | 0.999 sec/iter
# Epoch: 492 | Batch: 003 / 011 | Total loss: 0.386 | Reg loss: 0.027 | Tree loss: 0.386 | Accuracy: 0.844500 | 0.999 sec/iter
# Epoch: 492 | Batch: 004 / 011 | Total loss: 0.395 | Reg loss: 0.027 | Tree loss: 0.395 | Accuracy: 0.844500 | 0.999 sec/iter
# Epoch: 492 | Batch: 005 / 011 | Total loss: 0.392 | Reg loss: 0.027 | Tree loss: 0.392 | Accuracy: 0.839000 | 0.999 sec/iter
# Epoch: 492 | Batch: 006 / 011 | Total loss: 0.390 | Reg loss: 0.027 | Tree loss: 0.390 | Accuracy: 0.811000 | 0.999 sec/iter
# Epoch: 492 | Batch: 007 / 011 | Total loss: 0.395 | Reg loss: 0.027 | Tree loss: 0.395 | Accuracy: 0.813500 | 0.999 sec/iter
# Epoch: 492 | Batch: 008 / 011 | Total loss: 0.377 | Reg loss: 0.027 | Tree loss: 0.377 | Accuracy: 0.842000 | 0.999 sec/iter
# Epoch: 492 | Batch: 009 / 011 | Total loss: 0.388 | Reg loss: 0.027 | Tree loss: 0.388 | Accuracy: 0.849500 | 0.999 sec/iter
# Epoch: 492 | Batch: 010 / 011 | Total loss: 0.350 | Reg loss: 0.027 | Tree loss: 0.350 | Accuracy: 0.856655 | 0.999 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 493 | Batch: 000 / 011 | Total loss: 0.443 | Reg loss: 0.027 | Tree loss: 0.443 | Accuracy: 0.817500 | 0.999 sec/iter
# Epoch: 493 | Batch: 001 / 011 | Total loss: 0.441 | Reg loss: 0.027 | Tree loss: 0.441 | Accuracy: 0.813500 | 0.999 sec/iter
# Epoch: 493 | Batch: 002 / 011 | Total loss: 0.406 | Reg loss: 0.027 | Tree loss: 0.406 | Accuracy: 0.817500 | 0.999 sec/iter
# Epoch: 493 | Batch: 003 / 011 | Total loss: 0.404 | Reg loss: 0.027 | Tree loss: 0.404 | Accuracy: 0.837000 | 0.999 sec/iter
# Epoch: 493 | Batch: 004 / 011 | Total loss: 0.400 | Reg loss: 0.027 | Tree loss: 0.400 | Accuracy: 0.848000 | 0.999 sec/iter
# Epoch: 493 | Batch: 005 / 011 | Total loss: 0.388 | Reg loss: 0.027 | Tree loss: 0.388 | Accuracy: 0.834500 | 0.999 sec/iter
# Epoch: 493 | Batch: 006 / 011 | Total loss: 0.369 | Reg loss: 0.027 | Tree loss: 0.369 | Accuracy: 0.843000 | 0.999 sec/iter
# Epoch: 493 | Batch: 007 / 011 | Total loss: 0.387 | Reg loss: 0.027 | Tree loss: 0.387 | Accuracy: 0.825000 | 0.999 sec/iter
# Epoch: 493 | Batch: 008 / 011 | Total loss: 0.396 | Reg loss: 0.027 | Tree loss: 0.396 | Accuracy: 0.818500 | 0.999 sec/iter
# Epoch: 493 | Batch: 009 / 011 | Total loss: 0.373 | Reg loss: 0.027 | Tree loss: 0.373 | Accuracy: 0.857500 | 0.999 sec/iter
# Epoch: 493 | Batch: 010 / 011 | Total loss: 0.338 | Reg loss: 0.027 | Tree loss: 0.338 | Accuracy: 0.856655 | 0.999 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 494 | Batch: 000 / 011 | Total loss: 0.422 | Reg loss: 0.027 | Tree loss: 0.422 | Accuracy: 0.822500 | 0.999 sec/iter
# Epoch: 494 | Batch: 001 / 011 | Total loss: 0.440 | Reg loss: 0.027 | Tree loss: 0.440 | Accuracy: 0.813500 | 0.999 sec/iter
# Epoch: 494 | Batch: 002 / 011 | Total loss: 0.413 | Reg loss: 0.027 | Tree loss: 0.413 | Accuracy: 0.820500 | 0.999 sec/iter
# Epoch: 494 | Batch: 003 / 011 | Total loss: 0.391 | Reg loss: 0.027 | Tree loss: 0.391 | Accuracy: 0.850000 | 0.999 sec/iter
# Epoch: 494 | Batch: 004 / 011 | Total loss: 0.376 | Reg loss: 0.027 | Tree loss: 0.376 | Accuracy: 0.861000 | 0.999 sec/iter
# Epoch: 494 | Batch: 005 / 011 | Total loss: 0.391 | Reg loss: 0.027 | Tree loss: 0.391 | Accuracy: 0.847000 | 0.999 sec/iter
# Epoch: 494 | Batch: 006 / 011 | Total loss: 0.379 | Reg loss: 0.027 | Tree loss: 0.379 | Accuracy: 0.818000 | 0.999 sec/iter
# Epoch: 494 | Batch: 007 / 011 | Total loss: 0.390 | Reg loss: 0.027 | Tree loss: 0.390 | Accuracy: 0.826000 | 0.999 sec/iter
# Epoch: 494 | Batch: 008 / 011 | Total loss: 0.393 | Reg loss: 0.027 | Tree loss: 0.393 | Accuracy: 0.816500 | 0.999 sec/iter
# Epoch: 494 | Batch: 009 / 011 | Total loss: 0.379 | Reg loss: 0.027 | Tree loss: 0.379 | Accuracy: 0.843000 | 0.999 sec/iter
# Epoch: 494 | Batch: 010 / 011 | Total loss: 0.384 | Reg loss: 0.027 | Tree loss: 0.384 | Accuracy: 0.883959 | 0.999 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 495 | Batch: 000 / 011 | Total loss: 0.440 | Reg loss: 0.027 | Tree loss: 0.440 | Accuracy: 0.812500 | 0.999 sec/iter
# Epoch: 495 | Batch: 001 / 011 | Total loss: 0.426 | Reg loss: 0.027 | Tree loss: 0.426 | Accuracy: 0.829500 | 0.999 sec/iter
# Epoch: 495 | Batch: 002 / 011 | Total loss: 0.403 | Reg loss: 0.027 | Tree loss: 0.403 | Accuracy: 0.822000 | 0.999 sec/iter
# Epoch: 495 | Batch: 003 / 011 | Total loss: 0.382 | Reg loss: 0.027 | Tree loss: 0.382 | Accuracy: 0.848000 | 0.999 sec/iter
# Epoch: 495 | Batch: 004 / 011 | Total loss: 0.399 | Reg loss: 0.027 | Tree loss: 0.399 | Accuracy: 0.852000 | 0.999 sec/iter
# Epoch: 495 | Batch: 005 / 011 | Total loss: 0.386 | Reg loss: 0.027 | Tree loss: 0.386 | Accuracy: 0.850000 | 0.999 sec/iter
# Epoch: 495 | Batch: 006 / 011 | Total loss: 0.386 | Reg loss: 0.027 | Tree loss: 0.386 | Accuracy: 0.828000 | 0.999 sec/iter
# Epoch: 495 | Batch: 007 / 011 | Total loss: 0.388 | Reg loss: 0.027 | Tree loss: 0.388 | Accuracy: 0.829000 | 0.999 sec/iter
# Epoch: 495 | Batch: 008 / 011 | Total loss: 0.380 | Reg loss: 0.027 | Tree loss: 0.380 | Accuracy: 0.838000 | 0.999 sec/iter
# Epoch: 495 | Batch: 009 / 011 | Total loss: 0.380 | Reg loss: 0.027 | Tree loss: 0.380 | Accuracy: 0.860500 | 0.999 sec/iter
# Epoch: 495 | Batch: 010 / 011 | Total loss: 0.333 | Reg loss: 0.027 | Tree loss: 0.333 | Accuracy: 0.897611 | 0.999 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 496 | Batch: 000 / 011 | Total loss: 0.425 | Reg loss: 0.027 | Tree loss: 0.425 | Accuracy: 0.819000 | 0.999 sec/iter
# Epoch: 496 | Batch: 001 / 011 | Total loss: 0.423 | Reg loss: 0.027 | Tree loss: 0.423 | Accuracy: 0.828000 | 0.999 sec/iter
# Epoch: 496 | Batch: 002 / 011 | Total loss: 0.431 | Reg loss: 0.027 | Tree loss: 0.431 | Accuracy: 0.813500 | 0.999 sec/iter
# Epoch: 496 | Batch: 003 / 011 | Total loss: 0.382 | Reg loss: 0.027 | Tree loss: 0.382 | Accuracy: 0.850000 | 0.999 sec/iter
# Epoch: 496 | Batch: 004 / 011 | Total loss: 0.388 | Reg loss: 0.027 | Tree loss: 0.388 | Accuracy: 0.847000 | 0.999 sec/iter
# Epoch: 496 | Batch: 005 / 011 | Total loss: 0.376 | Reg loss: 0.027 | Tree loss: 0.376 | Accuracy: 0.860500 | 0.999 sec/iter
# Epoch: 496 | Batch: 006 / 011 | Total loss: 0.385 | Reg loss: 0.027 | Tree loss: 0.385 | Accuracy: 0.829500 | 0.999 sec/iter
# Epoch: 496 | Batch: 007 / 011 | Total loss: 0.411 | Reg loss: 0.027 | Tree loss: 0.411 | Accuracy: 0.798000 | 0.999 sec/iter
# Epoch: 496 | Batch: 008 / 011 | Total loss: 0.374 | Reg loss: 0.027 | Tree loss: 0.374 | Accuracy: 0.830500 | 0.999 sec/iter
# Epoch: 496 | Batch: 009 / 011 | Total loss: 0.383 | Reg loss: 0.027 | Tree loss: 0.383 | Accuracy: 0.854000 | 0.999 sec/iter
# Epoch: 496 | Batch: 010 / 011 | Total loss: 0.321 | Reg loss: 0.027 | Tree loss: 0.321 | Accuracy: 0.897611 | 0.999 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 497 | Batch: 000 / 011 | Total loss: 0.418 | Reg loss: 0.027 | Tree loss: 0.418 | Accuracy: 0.823500 | 0.999 sec/iter
# Epoch: 497 | Batch: 001 / 011 | Total loss: 0.433 | Reg loss: 0.027 | Tree loss: 0.433 | Accuracy: 0.814500 | 0.999 sec/iter
# Epoch: 497 | Batch: 002 / 011 | Total loss: 0.392 | Reg loss: 0.027 | Tree loss: 0.392 | Accuracy: 0.846000 | 0.999 sec/iter
# Epoch: 497 | Batch: 003 / 011 | Total loss: 0.390 | Reg loss: 0.027 | Tree loss: 0.390 | Accuracy: 0.842000 | 0.999 sec/iter
# Epoch: 497 | Batch: 004 / 011 | Total loss: 0.387 | Reg loss: 0.027 | Tree loss: 0.387 | Accuracy: 0.857500 | 0.999 sec/iter
# Epoch: 497 | Batch: 005 / 011 | Total loss: 0.408 | Reg loss: 0.027 | Tree loss: 0.408 | Accuracy: 0.841000 | 0.999 sec/iter
# Epoch: 497 | Batch: 006 / 011 | Total loss: 0.371 | Reg loss: 0.027 | Tree loss: 0.371 | Accuracy: 0.831000 | 0.999 sec/iter
# Epoch: 497 | Batch: 007 / 011 | Total loss: 0.398 | Reg loss: 0.027 | Tree loss: 0.398 | Accuracy: 0.823000 | 0.999 sec/iter
# Epoch: 497 | Batch: 008 / 011 | Total loss: 0.365 | Reg loss: 0.027 | Tree loss: 0.365 | Accuracy: 0.853000 | 0.999 sec/iter
# Epoch: 497 | Batch: 009 / 011 | Total loss: 0.383 | Reg loss: 0.027 | Tree loss: 0.383 | Accuracy: 0.863000 | 0.999 sec/iter
# Epoch: 497 | Batch: 010 / 011 | Total loss: 0.360 | Reg loss: 0.027 | Tree loss: 0.360 | Accuracy: 0.863481 | 0.999 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 498 | Batch: 000 / 011 | Total loss: 0.418 | Reg loss: 0.027 | Tree loss: 0.418 | Accuracy: 0.826500 | 0.999 sec/iter
# Epoch: 498 | Batch: 001 / 011 | Total loss: 0.428 | Reg loss: 0.027 | Tree loss: 0.428 | Accuracy: 0.813500 | 0.999 sec/iter
# Epoch: 498 | Batch: 002 / 011 | Total loss: 0.416 | Reg loss: 0.027 | Tree loss: 0.416 | Accuracy: 0.825000 | 0.999 sec/iter
# Epoch: 498 | Batch: 003 / 011 | Total loss: 0.387 | Reg loss: 0.027 | Tree loss: 0.387 | Accuracy: 0.840000 | 0.999 sec/iter
# Epoch: 498 | Batch: 004 / 011 | Total loss: 0.381 | Reg loss: 0.027 | Tree loss: 0.381 | Accuracy: 0.861500 | 0.999 sec/iter
# Epoch: 498 | Batch: 005 / 011 | Total loss: 0.387 | Reg loss: 0.027 | Tree loss: 0.387 | Accuracy: 0.845000 | 0.999 sec/iter
# Epoch: 498 | Batch: 006 / 011 | Total loss: 0.390 | Reg loss: 0.027 | Tree loss: 0.390 | Accuracy: 0.824500 | 0.999 sec/iter
# Epoch: 498 | Batch: 007 / 011 | Total loss: 0.399 | Reg loss: 0.027 | Tree loss: 0.399 | Accuracy: 0.819000 | 0.999 sec/iter
# Epoch: 498 | Batch: 008 / 011 | Total loss: 0.373 | Reg loss: 0.027 | Tree loss: 0.373 | Accuracy: 0.838000 | 0.999 sec/iter
# Epoch: 498 | Batch: 009 / 011 | Total loss: 0.372 | Reg loss: 0.027 | Tree loss: 0.372 | Accuracy: 0.853500 | 0.999 sec/iter
# Epoch: 498 | Batch: 010 / 011 | Total loss: 0.349 | Reg loss: 0.027 | Tree loss: 0.349 | Accuracy: 0.883959 | 0.999 sec/iter
# Average sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# layer 7: 0.9723756906077345
# layer 8: 0.9723756906077345
# Epoch: 499 | Batch: 000 / 011 | Total loss: 0.427 | Reg loss: 0.027 | Tree loss: 0.427 | Accuracy: 0.830000 | 0.999 sec/iter
# Epoch: 499 | Batch: 001 / 011 | Total loss: 0.416 | Reg loss: 0.027 | Tree loss: 0.416 | Accuracy: 0.833000 | 0.999 sec/iter
# Epoch: 499 | Batch: 002 / 011 | Total loss: 0.407 | Reg loss: 0.027 | Tree loss: 0.407 | Accuracy: 0.835000 | 0.999 sec/iter
# Epoch: 499 | Batch: 003 / 011 | Total loss: 0.394 | Reg loss: 0.027 | Tree loss: 0.394 | Accuracy: 0.827500 | 0.999 sec/iter
# Epoch: 499 | Batch: 004 / 011 | Total loss: 0.385 | Reg loss: 0.027 | Tree loss: 0.385 | Accuracy: 0.858500 | 0.999 sec/iter
# Epoch: 499 | Batch: 005 / 011 | Total loss: 0.401 | Reg loss: 0.027 | Tree loss: 0.401 | Accuracy: 0.837500 | 0.999 sec/iter
# Epoch: 499 | Batch: 006 / 011 | Total loss: 0.389 | Reg loss: 0.027 | Tree loss: 0.389 | Accuracy: 0.818000 | 0.998 sec/iter
# Epoch: 499 | Batch: 007 / 011 | Total loss: 0.398 | Reg loss: 0.027 | Tree loss: 0.398 | Accuracy: 0.812000 | 0.998 sec/iter
# Epoch: 499 | Batch: 008 / 011 | Total loss: 0.377 | Reg loss: 0.027 | Tree loss: 0.377 | Accuracy: 0.834000 | 0.998 sec/iter
# Epoch: 499 | Batch: 009 / 011 | Total loss: 0.364 | Reg loss: 0.027 | Tree loss: 0.364 | Accuracy: 0.860000 | 0.998 sec/iter
# Epoch: 499 | Batch: 010 / 011 | Total loss: 0.363 | Reg loss: 0.027 | Tree loss: 0.363 | Accuracy: 0.890785 | 0.998 sec/iter

# %%
plt.figure(figsize=(10, 5))
plt.ylabel("Accuracy")
plt.xlabel('Iteration')
plt.plot(accs, label='Accuracy vs iteration')
plt.show()

# %%
plt.figure()
plt.ylabel("Loss")
plt.xlabel('Iteration')
plt.plot(losses, label='Loss vs iteration')
plt.yscale("log")
plt.show()

plt.figure()
weights = tree.inner_nodes.weight.cpu().detach().numpy().flatten()
plt.hist(weights, bins=500)
weights_std = np.std(weights)
weights_mean = np.mean(weights)
plt.axvline(weights_mean + weights_std, color='r')
plt.axvline(weights_mean - weights_std, color='r')
plt.title(f"Mean: {weights_mean}   |   STD: {weights_std}")
plt.yscale("log")
plt.show()

# %% [markdown]
# # Tree Visualization

# %%
plt.figure(figsize=(15, 10), dpi=80)
avg_height, root = tree.visualize()
# Out:
# Average height: 5.944444444444445

# %% [markdown]
# # Extract Rules

# %% [markdown]
# # Accumulate samples in the leaves

# %%
print(f"Number of patterns: {len(root.get_leaves())}")
# Out:
# Number of patterns: 18

# %%
method = 'MLE'

# %%
root.clear_leaves_samples()

with torch.no_grad():
    for batch_idx, (data, target) in enumerate(tree_loader):
        root.accumulate_samples(data, method)
# Out:
# /home/eitan.k/.local/lib/python3.6/site-packages/torch/nn/functional.py:1709: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %% [markdown]
# # Tighten boundaries

# %%
signal_names = dataset.dataset.all_signals
normalizers = torch.tensor([])
attr_names = []
for signal_name in signal_names:
    attr_names += [f"T{i}.{signal_name}" for i in range(sampled.shape[-1])]
    sensor_norm = torch.tensor([torch.tensor(dataset.dataset.sensor_maxs[signal_name]) for _ in range(sampled.shape[-1])])
    normalizers = torch.cat([normalizers, sensor_norm])
    

# print(attr_names)
leaves = root.get_leaves()
sum_comprehensibility = 0

for pattern_counter, leaf in enumerate(leaves):
    leaf.reset_path()
    leaf.tighten_with_accumulated_samples()
    conds = leaf.get_path_conditions(attr_names)
    for cond in conds:
        cond.weights = cond.weights / normalizers
    print(f"============== Pattern {pattern_counter + 1} ==============")
    sum_comprehensibility += sum([cond.comprehensibility for cond in conds])
    
print(f"Average comprehensibility: {sum_comprehensibility / len(leaves)}")
# Out:
# ============== Pattern 1 ==============
# ============== Pattern 2 ==============
# ============== Pattern 3 ==============
# ============== Pattern 4 ==============
# ============== Pattern 5 ==============
# ============== Pattern 6 ==============
# ============== Pattern 7 ==============
# ============== Pattern 8 ==============
# ============== Pattern 9 ==============
# ============== Pattern 10 ==============
# ============== Pattern 11 ==============
# ============== Pattern 12 ==============
# ============== Pattern 13 ==============
# ============== Pattern 14 ==============
# ============== Pattern 15 ==============
# ============== Pattern 16 ==============
# ============== Pattern 17 ==============
# ============== Pattern 18 ==============
# Average comprehensibility: 54.666666666666664
# /home/eitan.k/EntangledExplainableClustering/soft_decision_tree/sdt_model.py:14: RuntimeWarning: divide by zero encountered in log
#   return np.log(1 / (1 - x))

# %%
# prune_tree(tree, factor=1.5)
correct = 0
tree = tree.eval()
with torch.no_grad():
    for batch_idx, (data, target) in enumerate(tree_loader):
            data, target = data.to(device), target.to(device)
            output = tree.forward(data)
            pred = output.data.max(1)[1]
            correct += pred.eq(target.view(-1).data).sum()

print(f"Accuracy: {correct / len(tree_loader.dataset)}")
# Out:
# Accuracy: 0.8189523220062256

# %%
print(f"Sparseness: {sparseness(tree.inner_nodes.weight)}")
layer = 0
sps = []
for i in range(tree.inner_nodes.weight.shape[0]):
    cur_layer = np.floor(np.log2(i+1))
    if cur_layer != layer:
        print(f"layer {layer}: {np.mean(sps)}")
        sps = []
        layer = cur_layer
    
    x_ = tree.inner_nodes.weight[i, :]
    sp = (len(x_) - torch.norm(x_, 0).item()) / len(x_)
    sps.append(sp)
# Out:
# Sparseness: 0.9723756906077345
# layer 0: 0.9723756906077348
# layer 1.0: 0.9723756906077348
# layer 2.0: 0.9723756906077348
# layer 3.0: 0.9723756906077348
# layer 4.0: 0.9723756906077348
# layer 5.0: 0.9723756906077348
# layer 6.0: 0.9723756906077349
# layer 7.0: 0.9723756906077345
# layer 8.0: 0.9723756906077345

# %% [markdown]
# ## Prune the weights

# %%
weights = tree.inner_nodes.weight.cpu().detach().numpy()
for i in range(0, weights.shape[0], 20):
    plt.figure()
    weights_layer = weights[i, :]
    plt.hist(weights_layer, bins=500)
    weights_std = np.std(weights_layer)
    weights_mean = np.mean(weights_layer)
    plt.axvline(weights_mean + weights_std, color='r')
    plt.axvline(weights_mean - weights_std, color='r')
    plt.title(f"Mean: {weights_mean}   |   STD: {weights_std}\n Kurtosis: {kurtosis(weights_layer)}")
    plt.yscale("log")
    plt.show()

# %% [markdown]
# ## Verify that the accuracy didn't change too much

# %%
correct = 0
tree_copy = tree_copy.eval()
with torch.no_grad():
    for batch_idx, (data, target) in enumerate(tree_loader):
            data, target = data.to(device), target.to(device)
            output = tree_copy.forward(data)
            pred = output.data.max(1)[1]
            correct += pred.eq(target.view(-1).data).sum()

print(f"Accuracy: {correct / len(tree_loader.dataset)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-2d39b7a9c923> in <module>
#       1 correct = 0
# ----> 2 tree_copy = tree_copy.eval()
#       3 with torch.no_grad():
#       4     for batch_idx, (data, target) in enumerate(tree_loader):
#       5             data, target = data.to(device), target.to(device)
#
# NameError: name 'tree_copy' is not defined

# %%
weights = tree_copy.inner_nodes.weight.cpu().detach().numpy()
for i in range(0, weights.shape[0], 20):
    plt.figure()
    weights_layer = weights[i, :]
    plt.hist(weights_layer, bins=500)
    weights_std = np.std(weights_layer)
    weights_mean = np.mean(weights_layer)
    plt.axvline(weights_mean + weights_std, color='r')
    plt.axvline(weights_mean - weights_std, color='r')
    plt.title(f"Mean: {weights_mean}   |   STD: {weights_std}")
    plt.yscale("log")
    plt.show()

# %%
stack = LifoQueue()
edge_stack = LifoQueue()
stack.put(root)
rule_counter = 0
root.reset()
while not stack.empty():
    node = stack.get()
    if node.is_leaf():
        print(f"============== Rule {rule_counter} ==============")
        for stack_node, cond in zip(stack.queue, edge_stack.queue[1:]):
            print(repr(stack_node.get_condition(attr_names)) + cond)
            print()
        
        rule_counter += 1
        edge_stack.get()
        continue
          
    if node.left is not None and not node.left.visited:
        stack.put(node)
        stack.put(node.left)
        node.left.visited = True
        edge_stack.put(' < 0')
        continue
        
    if node.right is not None and not node.right.visited:
        stack.put(node)
        stack.put(node.right)
        node.right.visited = True
        edge_stack.put(' > 0')
        continue
        
    if node is not root:
        edge_stack.get()
