# %%
# %matplotlib widget
# %matplotlib inline
import torch
import torch.nn as nn
import pickle
import time
import copy
import os
from queue import LifoQueue
from sklearn.cluster import DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.metrics import davies_bouldin_score
from scipy.stats import kurtosis
import matplotlib.pyplot as plt
import numpy as np
import sys
from sklearn.tree import DecisionTreeClassifier
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from tqdm.notebook import tqdm
from sklearn.metrics import pairwise_distances
import network.cpc
from network.cpc import CDCK2
from utils.MatplotlibUtils import reduce_dims_and_plot
from utils.ClassificationUtiols import onehot_coding
from soft_decision_tree.sdt_model import SDT
from sklearn import tree as tt

# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Load the model and the dataset

# %%
model_path = r'/home/eitan.k/EntangledExplainableClustering/knn_loss_batch_512_k_64/models/epoch_25.pt'
dataset_path = r'/home/eitan.k/EntangledExplainableClustering/knn_loss_batch_512_k_64/data/test_data.file'

print(f"Load the model from: {model_path}")
model = torch.load(model_path, map_location='cpu')

with open(dataset_path, 'rb') as fp:
    dataset = pickle.load(fp)

all_sensors = dataset.dataset.all_signals    
print(f"sensor names: ({len(all_sensors)} total)")

for s in all_sensors:
    print(f"- {s}")
    
print(f"Multihorizon size of the model: {model.timestep}")
print(f"Test split ratio: {len(dataset) / len(dataset.dataset)}")
print(f"Total number of windows in the dataset (without splitting): {len(dataset.dataset)}")
# Out:
# Load the model from: /home/eitan.k/EntangledExplainableClustering/knn_loss_batch_512_k_64/models/epoch_25.pt
# sensor names: (18 total)
# - speed
# - steering_angle
# - wheel_speed_0
# - wheel_speed_1
# - wheel_speed_2
# - wheel_speed_3
# - accelerometer_0
# - accelerometer_1
# - accelerometer_2
# - gyro_0
# - gyro_1
# - gyro_2
# - gyro_bias_0
# - gyro_bias_1
# - gyro_bias_2
# - gyro_uncalibrated_0
# - gyro_uncalibrated_1
# - gyro_uncalibrated_2
# Multihorizon size of the model: 30
# Test split ratio: 0.2
# Total number of windows in the dataset (without splitting): 101465

# %%
batch_size = 500
loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Extract representations

# %%
projections = torch.tensor([])
samples = torch.tensor([])
device = 'cuda'
model = model.to(device).eval()

with torch.no_grad():
    bar = tqdm(total=len(loader.dataset))
    for batch in loader:
        hidden = CDCK2.init_hidden(len(batch))
        batch = batch.to(device)
        hidden = hidden.to(device)

        y = model.predict(batch, hidden).detach().cpu()
        projections = torch.cat([projections, y.detach().cpu()])
        samples = torch.cat([samples, batch.detach().cpu()])
        bar.update(y.shape[0])
# Out:
#   0%|          | 0/20293 [00:00<?, ?it/s]

# %% [markdown]
# # Fit GMM and calculate indices

# %%
scores = []
best_score = float('inf')
clusters = None
range_ = list(range(5, 80))
for k in tqdm(range_):
    y = GaussianMixture(n_components=k).fit_predict(projections)
    cur_score = davies_bouldin_score(projections, y)
    scores.append(cur_score)
    
    if cur_score < best_score:
        best_score = cur_score
        clusters = y
# Out:
#   0%|          | 0/75 [00:00<?, ?it/s]

# %%
plt.figure()
plt.xlabel('Number of clusters')
plt.ylabel('DB Score')
plt.plot(range_, scores)
best_k = range_[np.argmin(scores)]
plt.axvline(best_k, color='r')
plt.show()

labels = set(clusters)
print(labels)
# Out:
# {0, 1, 2, 3, 4, 5}

# %%
distances = pairwise_distances(projections)
# distances = np.triu(distances)
distances_f = distances.flatten()

plt.matshow(distances)
plt.colorbar()
plt.figure()
plt.hist(distances_f[distances_f > 0], bins=1000)
plt.show()

# %% [markdown]
# # Visualize with T-SNE

# %%
perplexity = 200

p = reduce_dims_and_plot(projections,
                         y=clusters,
                         title=f'perplexity: {perplexity}',
                         file_name=None,
                         perplexity=perplexity,
                         library='Multicore-TSNE',
                         perform_PCA=False,
                         projected=None,
                         figure_type='2d',
                         show_figure=True,
                         close_figure=False,
                         text=None)

# %% [markdown]
# # Train a Soft-Decision-Tree given the self-labels

# %% [markdown]
# ## Prepare the dataset

# %%
# unnormalized_samples = samples.clone()

# for col, sensor in enumerate(tqdm(dataset.dataset.all_signals)):
#     denormalizer = dataset.dataset.get_denormalization_for_sensor(sensor)
#     unnormalized_samples[:, col, :] = denormalizer(unnormalized_samples[:, col, :])

sampled = samples[..., range(0, samples.shape[-1], 200)]

samples_f = sampled.flatten(1)
tree_dataset = list(zip(samples_f, clusters))
batch_size = 2000
tree_loader = torch.utils.data.DataLoader(tree_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # Define how we prune the weights of a node

# %%
def prune_node(node_weights, factor=1):
    w = node_weights.cpu().detach().numpy()
    mean_ = np.mean(w)
    std_ = np.std(w)
    node_weights[((mean_ - std_ * factor) < node_weights) & (node_weights < (mean_ + std_ * factor))] = 0
    return node_weights

def prune_node_keep(node_weights, keep=4):
    w = node_weights.cpu().detach().numpy()
    throw_idx = np.argsort(abs(w))[:-keep]
    node_weights[throw_idx] = 0
    return node_weights

def prune_tree(tree_, factor):
    new_weights = tree_.inner_nodes.weight.clone()
    for i in range(new_weights.shape[0]):
        res = prune_node_keep(new_weights[i, :], factor)
        new_weights[i, :] = res

    with torch.no_grad():
        tree_.inner_nodes.weight.copy_(new_weights)
        
def sparseness(x):
    s = []
    for i in range(x.shape[0]):
        x_ = x[i, :]
        sp = (len(x_) - torch.norm(x_, 0).item()) / len(x_)
        s.append(sp)
    return np.mean(s)

def compute_regularization_by_level(tree):
    total_reg = 0
    for i in range(tree.inner_nodes.weight.shape[0]):
        cur_level = np.floor(np.log2(i+1))
        node_reg = torch.norm(tree.inner_nodes.weight[i].view(-1), 2)
        total_reg += 2**(-cur_level) * node_reg
    return total_reg

def show_sparseness(tree):
    avg_sp = sparseness(tree.inner_nodes.weight)
    print(f"Average sparseness: {avg_sp}")
    layer = 0
    sps = []
    for i in range(tree.inner_nodes.weight.shape[0]):
        cur_layer = int(np.floor(np.log2(i+1)))
        if cur_layer != layer:
            print(f"layer {layer}: {np.mean(sps)}")
            sps = []
            layer = cur_layer

        x_ = tree.inner_nodes.weight[i, :]
        sp = (len(x_) - torch.norm(x_, 0).item()) / len(x_)
        sps.append(sp)
        
    return avg_sp

# %% [markdown]
# ## Training configurations

# %%
def do_epoch(model, loader, device, log_interval, losses, accs, epoch, iteration):
    model = model.train()
    for batch_idx, (data, target) in enumerate(loader):
        iteration += 1
        data, target = data.to(device), target.to(device)

        output, penalty = tree.forward(data)

        # Loss
        loss_tree = criterion(output, target.view(-1))

        # Penalty
        loss_tree += penalty

        # Sparse regularization
#         fc_params = torch.cat([x.view(-1) for x in tree.inner_nodes.parameters()])
#         regularization = sparsity_lamda * torch.norm(fc_params, 2)
        regularization = sparsity_lamda * compute_regularization_by_level(tree)
        loss = loss_tree

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        losses.append(loss.item())

        pred = output.data.max(1)[1]
        correct = pred.eq(target.view(-1).data).sum()
        accs.append(correct.item() / data.size()[0])

        # Print training status
        if batch_idx % log_interval == 0:
            print(f"Epoch: {epoch:02d} | Batch: {batch_idx:03d} / {len(loader):03d} | Total loss: {loss.item():.3f} | Reg loss: {regularization.item():.3f} | Tree loss: {loss_tree.item():.3f} | Accuracy: {correct.item() / data.size()[0]:03f} | {round((time.time() - start_time) / iteration, 3)} sec/iter")
            
    return iteration

# %%
lr = 5e-3
weight_decay = 5e-4
sparsity_lamda = 2e-3
epochs = 500
output_dim = len(set(clusters))
log_interval = 1
tree_depth = 8

# %%
tree = SDT(input_dim=samples_f.shape[1], output_dim=len(labels), depth=tree_depth, lamda=1e-3, use_cuda=True)
optimizer = torch.optim.Adam(tree.parameters(),
                                 lr=lr,
                                 weight_decay=weight_decay)
criterion = nn.CrossEntropyLoss()
tree = tree.to(device)
clf = DecisionTreeClassifier(max_depth=tree_depth).fit(samples_f, clusters)
print(f"DT accuracy: {clf.score(samples_f, clusters)}")
tree.initialize_from_decision_tree(clf)
# Out:
# DT accuracy: 0.978021978021978

# %%
losses = []
accs = []
sparsity = []

# %%
start_time = time.time()
iteration = 0
for epoch in range(epochs):
    # Training
    avg_sp = show_sparseness(tree)
    sparsity.append(avg_sp)
    iteration = do_epoch(tree, tree_loader, device, log_interval, losses, accs, epoch, iteration)
    
    if epoch % 1 == 0:
        prune_tree(tree, factor=5)
# Out:
# Average sparseness: 0.3451630375907269
# layer 0: 0.988950276243094
# layer 1: 0.988950276243094
# layer 2: 0.7417127071823204
# layer 3: 0.494475138121547
# layer 4: 0.494475138121547
# layer 5: 0.46357044198895025
# layer 6: 0.38630870165745856
# Epoch: 00 | Batch: 000 / 011 | Total loss: 1.763 | Reg loss: 0.014 | Tree loss: 1.763 | Accuracy: 0.367500 | 1.483 sec/iter
# Epoch: 00 | Batch: 001 / 011 | Total loss: 1.745 | Reg loss: 0.014 | Tree loss: 1.745 | Accuracy: 0.377500 | 0.836 sec/iter
# Epoch: 00 | Batch: 002 / 011 | Total loss: 1.739 | Reg loss: 0.014 | Tree loss: 1.739 | Accuracy: 0.347500 | 0.62 sec/iter
# Epoch: 00 | Batch: 003 / 011 | Total loss: 1.727 | Reg loss: 0.014 | Tree loss: 1.727 | Accuracy: 0.343000 | 0.515 sec/iter
# Epoch: 00 | Batch: 004 / 011 | Total loss: 1.712 | Reg loss: 0.014 | Tree loss: 1.712 | Accuracy: 0.351500 | 0.451 sec/iter
# Epoch: 00 | Batch: 005 / 011 | Total loss: 1.693 | Reg loss: 0.014 | Tree loss: 1.693 | Accuracy: 0.373500 | 0.407 sec/iter
# Epoch: 00 | Batch: 006 / 011 | Total loss: 1.687 | Reg loss: 0.014 | Tree loss: 1.687 | Accuracy: 0.396000 | 0.378 sec/iter
# Epoch: 00 | Batch: 007 / 011 | Total loss: 1.678 | Reg loss: 0.014 | Tree loss: 1.678 | Accuracy: 0.408000 | 0.356 sec/iter
# Epoch: 00 | Batch: 008 / 011 | Total loss: 1.669 | Reg loss: 0.014 | Tree loss: 1.669 | Accuracy: 0.409000 | 0.339 sec/iter
# Epoch: 00 | Batch: 009 / 011 | Total loss: 1.664 | Reg loss: 0.014 | Tree loss: 1.664 | Accuracy: 0.407500 | 0.326 sec/iter
# Epoch: 00 | Batch: 010 / 011 | Total loss: 1.623 | Reg loss: 0.014 | Tree loss: 1.623 | Accuracy: 0.488055 | 0.315 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 01 | Batch: 000 / 011 | Total loss: 1.743 | Reg loss: 0.011 | Tree loss: 1.743 | Accuracy: 0.370000 | 0.519 sec/iter
# Epoch: 01 | Batch: 001 / 011 | Total loss: 1.732 | Reg loss: 0.011 | Tree loss: 1.732 | Accuracy: 0.361500 | 0.495 sec/iter
# Epoch: 01 | Batch: 002 / 011 | Total loss: 1.717 | Reg loss: 0.012 | Tree loss: 1.717 | Accuracy: 0.407000 | 0.474 sec/iter
# Epoch: 01 | Batch: 003 / 011 | Total loss: 1.697 | Reg loss: 0.012 | Tree loss: 1.697 | Accuracy: 0.431000 | 0.456 sec/iter
# Epoch: 01 | Batch: 004 / 011 | Total loss: 1.691 | Reg loss: 0.012 | Tree loss: 1.691 | Accuracy: 0.408500 | 0.441 sec/iter
# Epoch: 01 | Batch: 005 / 011 | Total loss: 1.664 | Reg loss: 0.012 | Tree loss: 1.664 | Accuracy: 0.443000 | 0.427 sec/iter
# Epoch: 01 | Batch: 006 / 011 | Total loss: 1.661 | Reg loss: 0.012 | Tree loss: 1.661 | Accuracy: 0.419500 | 0.416 sec/iter
# Epoch: 01 | Batch: 007 / 011 | Total loss: 1.640 | Reg loss: 0.013 | Tree loss: 1.640 | Accuracy: 0.433000 | 0.406 sec/iter
# Epoch: 01 | Batch: 008 / 011 | Total loss: 1.630 | Reg loss: 0.013 | Tree loss: 1.630 | Accuracy: 0.433000 | 0.396 sec/iter
# Epoch: 01 | Batch: 009 / 011 | Total loss: 1.626 | Reg loss: 0.013 | Tree loss: 1.626 | Accuracy: 0.415500 | 0.387 sec/iter
# Epoch: 01 | Batch: 010 / 011 | Total loss: 1.618 | Reg loss: 0.014 | Tree loss: 1.618 | Accuracy: 0.423208 | 0.379 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 02 | Batch: 000 / 011 | Total loss: 1.729 | Reg loss: 0.012 | Tree loss: 1.729 | Accuracy: 0.395000 | 0.482 sec/iter
# Epoch: 02 | Batch: 001 / 011 | Total loss: 1.708 | Reg loss: 0.012 | Tree loss: 1.708 | Accuracy: 0.418500 | 0.471 sec/iter
# Epoch: 02 | Batch: 002 / 011 | Total loss: 1.693 | Reg loss: 0.012 | Tree loss: 1.693 | Accuracy: 0.428500 | 0.46 sec/iter
# Epoch: 02 | Batch: 003 / 011 | Total loss: 1.674 | Reg loss: 0.012 | Tree loss: 1.674 | Accuracy: 0.434000 | 0.451 sec/iter
# Epoch: 02 | Batch: 004 / 011 | Total loss: 1.656 | Reg loss: 0.012 | Tree loss: 1.656 | Accuracy: 0.435000 | 0.442 sec/iter
# Epoch: 02 | Batch: 005 / 011 | Total loss: 1.643 | Reg loss: 0.012 | Tree loss: 1.643 | Accuracy: 0.426500 | 0.433 sec/iter
# Epoch: 02 | Batch: 006 / 011 | Total loss: 1.620 | Reg loss: 0.013 | Tree loss: 1.620 | Accuracy: 0.461000 | 0.426 sec/iter
# Epoch: 02 | Batch: 007 / 011 | Total loss: 1.612 | Reg loss: 0.013 | Tree loss: 1.612 | Accuracy: 0.427500 | 0.418 sec/iter
# Epoch: 02 | Batch: 008 / 011 | Total loss: 1.592 | Reg loss: 0.013 | Tree loss: 1.592 | Accuracy: 0.459500 | 0.411 sec/iter
# Epoch: 02 | Batch: 009 / 011 | Total loss: 1.585 | Reg loss: 0.014 | Tree loss: 1.585 | Accuracy: 0.444000 | 0.404 sec/iter
# Epoch: 02 | Batch: 010 / 011 | Total loss: 1.579 | Reg loss: 0.014 | Tree loss: 1.579 | Accuracy: 0.433447 | 0.398 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 03 | Batch: 000 / 011 | Total loss: 1.702 | Reg loss: 0.012 | Tree loss: 1.702 | Accuracy: 0.456500 | 0.394 sec/iter
# Epoch: 03 | Batch: 001 / 011 | Total loss: 1.681 | Reg loss: 0.012 | Tree loss: 1.681 | Accuracy: 0.471500 | 0.388 sec/iter
# Epoch: 03 | Batch: 002 / 011 | Total loss: 1.667 | Reg loss: 0.012 | Tree loss: 1.667 | Accuracy: 0.452000 | 0.383 sec/iter
# Epoch: 03 | Batch: 003 / 011 | Total loss: 1.653 | Reg loss: 0.012 | Tree loss: 1.653 | Accuracy: 0.433500 | 0.378 sec/iter
# Epoch: 03 | Batch: 004 / 011 | Total loss: 1.623 | Reg loss: 0.013 | Tree loss: 1.623 | Accuracy: 0.440000 | 0.374 sec/iter
# Epoch: 03 | Batch: 005 / 011 | Total loss: 1.610 | Reg loss: 0.013 | Tree loss: 1.610 | Accuracy: 0.446500 | 0.37 sec/iter
# Epoch: 03 | Batch: 006 / 011 | Total loss: 1.589 | Reg loss: 0.013 | Tree loss: 1.589 | Accuracy: 0.463500 | 0.367 sec/iter
# Epoch: 03 | Batch: 007 / 011 | Total loss: 1.574 | Reg loss: 0.013 | Tree loss: 1.574 | Accuracy: 0.469000 | 0.363 sec/iter
# Epoch: 03 | Batch: 008 / 011 | Total loss: 1.563 | Reg loss: 0.014 | Tree loss: 1.563 | Accuracy: 0.479000 | 0.359 sec/iter
# Epoch: 03 | Batch: 009 / 011 | Total loss: 1.538 | Reg loss: 0.014 | Tree loss: 1.538 | Accuracy: 0.522000 | 0.356 sec/iter
# Epoch: 03 | Batch: 010 / 011 | Total loss: 1.541 | Reg loss: 0.014 | Tree loss: 1.541 | Accuracy: 0.515358 | 0.352 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 04 | Batch: 000 / 011 | Total loss: 1.684 | Reg loss: 0.013 | Tree loss: 1.684 | Accuracy: 0.473000 | 0.405 sec/iter
# Epoch: 04 | Batch: 001 / 011 | Total loss: 1.664 | Reg loss: 0.013 | Tree loss: 1.664 | Accuracy: 0.466000 | 0.401 sec/iter
# Epoch: 04 | Batch: 002 / 011 | Total loss: 1.639 | Reg loss: 0.013 | Tree loss: 1.639 | Accuracy: 0.471000 | 0.397 sec/iter
# Epoch: 04 | Batch: 003 / 011 | Total loss: 1.620 | Reg loss: 0.013 | Tree loss: 1.620 | Accuracy: 0.451500 | 0.393 sec/iter
# Epoch: 04 | Batch: 004 / 011 | Total loss: 1.593 | Reg loss: 0.013 | Tree loss: 1.593 | Accuracy: 0.462500 | 0.389 sec/iter
# Epoch: 04 | Batch: 005 / 011 | Total loss: 1.569 | Reg loss: 0.013 | Tree loss: 1.569 | Accuracy: 0.484500 | 0.385 sec/iter
# Epoch: 04 | Batch: 006 / 011 | Total loss: 1.545 | Reg loss: 0.014 | Tree loss: 1.545 | Accuracy: 0.516000 | 0.382 sec/iter
# Epoch: 04 | Batch: 007 / 011 | Total loss: 1.525 | Reg loss: 0.014 | Tree loss: 1.525 | Accuracy: 0.525000 | 0.379 sec/iter
# Epoch: 04 | Batch: 008 / 011 | Total loss: 1.506 | Reg loss: 0.014 | Tree loss: 1.506 | Accuracy: 0.537500 | 0.376 sec/iter
# Epoch: 04 | Batch: 009 / 011 | Total loss: 1.497 | Reg loss: 0.015 | Tree loss: 1.497 | Accuracy: 0.576000 | 0.373 sec/iter
# Epoch: 04 | Batch: 010 / 011 | Total loss: 1.471 | Reg loss: 0.015 | Tree loss: 1.471 | Accuracy: 0.621160 | 0.37 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 05 | Batch: 000 / 011 | Total loss: 1.656 | Reg loss: 0.013 | Tree loss: 1.656 | Accuracy: 0.532500 | 0.403 sec/iter
# Epoch: 05 | Batch: 001 / 011 | Total loss: 1.635 | Reg loss: 0.013 | Tree loss: 1.635 | Accuracy: 0.500500 | 0.399 sec/iter
# Epoch: 05 | Batch: 002 / 011 | Total loss: 1.607 | Reg loss: 0.013 | Tree loss: 1.607 | Accuracy: 0.493500 | 0.395 sec/iter
# Epoch: 05 | Batch: 003 / 011 | Total loss: 1.571 | Reg loss: 0.013 | Tree loss: 1.571 | Accuracy: 0.527000 | 0.392 sec/iter
# Epoch: 05 | Batch: 004 / 011 | Total loss: 1.556 | Reg loss: 0.014 | Tree loss: 1.556 | Accuracy: 0.521500 | 0.389 sec/iter
# Epoch: 05 | Batch: 005 / 011 | Total loss: 1.536 | Reg loss: 0.014 | Tree loss: 1.536 | Accuracy: 0.558000 | 0.385 sec/iter
# Epoch: 05 | Batch: 006 / 011 | Total loss: 1.502 | Reg loss: 0.014 | Tree loss: 1.502 | Accuracy: 0.590000 | 0.382 sec/iter
# Epoch: 05 | Batch: 007 / 011 | Total loss: 1.483 | Reg loss: 0.015 | Tree loss: 1.483 | Accuracy: 0.604000 | 0.379 sec/iter
# Epoch: 05 | Batch: 008 / 011 | Total loss: 1.452 | Reg loss: 0.015 | Tree loss: 1.452 | Accuracy: 0.627500 | 0.377 sec/iter
# Epoch: 05 | Batch: 009 / 011 | Total loss: 1.437 | Reg loss: 0.015 | Tree loss: 1.437 | Accuracy: 0.613000 | 0.374 sec/iter
# Epoch: 05 | Batch: 010 / 011 | Total loss: 1.423 | Reg loss: 0.016 | Tree loss: 1.423 | Accuracy: 0.641638 | 0.372 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 06 | Batch: 000 / 011 | Total loss: 1.625 | Reg loss: 0.014 | Tree loss: 1.625 | Accuracy: 0.547500 | 0.407 sec/iter
# Epoch: 06 | Batch: 001 / 011 | Total loss: 1.595 | Reg loss: 0.014 | Tree loss: 1.595 | Accuracy: 0.529000 | 0.405 sec/iter
# Epoch: 06 | Batch: 002 / 011 | Total loss: 1.566 | Reg loss: 0.014 | Tree loss: 1.566 | Accuracy: 0.511000 | 0.402 sec/iter
# Epoch: 06 | Batch: 003 / 011 | Total loss: 1.543 | Reg loss: 0.014 | Tree loss: 1.543 | Accuracy: 0.503500 | 0.399 sec/iter
# Epoch: 06 | Batch: 004 / 011 | Total loss: 1.513 | Reg loss: 0.014 | Tree loss: 1.513 | Accuracy: 0.502000 | 0.397 sec/iter
# Epoch: 06 | Batch: 005 / 011 | Total loss: 1.486 | Reg loss: 0.015 | Tree loss: 1.486 | Accuracy: 0.522000 | 0.394 sec/iter
# Epoch: 06 | Batch: 006 / 011 | Total loss: 1.461 | Reg loss: 0.015 | Tree loss: 1.461 | Accuracy: 0.566000 | 0.392 sec/iter
# Epoch: 06 | Batch: 007 / 011 | Total loss: 1.441 | Reg loss: 0.015 | Tree loss: 1.441 | Accuracy: 0.587500 | 0.389 sec/iter
# Epoch: 06 | Batch: 008 / 011 | Total loss: 1.416 | Reg loss: 0.016 | Tree loss: 1.416 | Accuracy: 0.600500 | 0.387 sec/iter
# Epoch: 06 | Batch: 009 / 011 | Total loss: 1.384 | Reg loss: 0.016 | Tree loss: 1.384 | Accuracy: 0.628000 | 0.385 sec/iter
# Epoch: 06 | Batch: 010 / 011 | Total loss: 1.381 | Reg loss: 0.016 | Tree loss: 1.381 | Accuracy: 0.655290 | 0.383 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 07 | Batch: 000 / 011 | Total loss: 1.590 | Reg loss: 0.014 | Tree loss: 1.590 | Accuracy: 0.554000 | 0.413 sec/iter
# Epoch: 07 | Batch: 001 / 011 | Total loss: 1.557 | Reg loss: 0.014 | Tree loss: 1.557 | Accuracy: 0.553000 | 0.411 sec/iter
# Epoch: 07 | Batch: 002 / 011 | Total loss: 1.525 | Reg loss: 0.015 | Tree loss: 1.525 | Accuracy: 0.576000 | 0.409 sec/iter
# Epoch: 07 | Batch: 003 / 011 | Total loss: 1.499 | Reg loss: 0.015 | Tree loss: 1.499 | Accuracy: 0.584500 | 0.406 sec/iter
# Epoch: 07 | Batch: 004 / 011 | Total loss: 1.467 | Reg loss: 0.015 | Tree loss: 1.467 | Accuracy: 0.604000 | 0.403 sec/iter
# Epoch: 07 | Batch: 005 / 011 | Total loss: 1.435 | Reg loss: 0.015 | Tree loss: 1.435 | Accuracy: 0.615500 | 0.401 sec/iter
# Epoch: 07 | Batch: 006 / 011 | Total loss: 1.401 | Reg loss: 0.016 | Tree loss: 1.401 | Accuracy: 0.640500 | 0.399 sec/iter
# Epoch: 07 | Batch: 007 / 011 | Total loss: 1.380 | Reg loss: 0.016 | Tree loss: 1.380 | Accuracy: 0.637000 | 0.396 sec/iter
# Epoch: 07 | Batch: 008 / 011 | Total loss: 1.381 | Reg loss: 0.016 | Tree loss: 1.381 | Accuracy: 0.632000 | 0.394 sec/iter
# Epoch: 07 | Batch: 009 / 011 | Total loss: 1.351 | Reg loss: 0.017 | Tree loss: 1.351 | Accuracy: 0.642500 | 0.392 sec/iter
# Epoch: 07 | Batch: 010 / 011 | Total loss: 1.309 | Reg loss: 0.017 | Tree loss: 1.309 | Accuracy: 0.679181 | 0.39 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 08 | Batch: 000 / 011 | Total loss: 1.568 | Reg loss: 0.015 | Tree loss: 1.568 | Accuracy: 0.538000 | 0.4 sec/iter
# Epoch: 08 | Batch: 001 / 011 | Total loss: 1.524 | Reg loss: 0.015 | Tree loss: 1.524 | Accuracy: 0.563000 | 0.398 sec/iter
# Epoch: 08 | Batch: 002 / 011 | Total loss: 1.476 | Reg loss: 0.015 | Tree loss: 1.476 | Accuracy: 0.578000 | 0.395 sec/iter
# Epoch: 08 | Batch: 003 / 011 | Total loss: 1.446 | Reg loss: 0.015 | Tree loss: 1.446 | Accuracy: 0.586500 | 0.393 sec/iter
# Epoch: 08 | Batch: 004 / 011 | Total loss: 1.432 | Reg loss: 0.016 | Tree loss: 1.432 | Accuracy: 0.576500 | 0.391 sec/iter
# Epoch: 08 | Batch: 005 / 011 | Total loss: 1.385 | Reg loss: 0.016 | Tree loss: 1.385 | Accuracy: 0.638000 | 0.389 sec/iter
# Epoch: 08 | Batch: 006 / 011 | Total loss: 1.364 | Reg loss: 0.016 | Tree loss: 1.364 | Accuracy: 0.608000 | 0.387 sec/iter
# Epoch: 08 | Batch: 007 / 011 | Total loss: 1.337 | Reg loss: 0.016 | Tree loss: 1.337 | Accuracy: 0.625000 | 0.385 sec/iter
# Epoch: 08 | Batch: 008 / 011 | Total loss: 1.317 | Reg loss: 0.017 | Tree loss: 1.317 | Accuracy: 0.640500 | 0.383 sec/iter
# Epoch: 08 | Batch: 009 / 011 | Total loss: 1.279 | Reg loss: 0.017 | Tree loss: 1.279 | Accuracy: 0.674000 | 0.381 sec/iter
# Epoch: 08 | Batch: 010 / 011 | Total loss: 1.261 | Reg loss: 0.017 | Tree loss: 1.261 | Accuracy: 0.689420 | 0.379 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 09 | Batch: 000 / 011 | Total loss: 1.520 | Reg loss: 0.016 | Tree loss: 1.520 | Accuracy: 0.573500 | 0.379 sec/iter
# Epoch: 09 | Batch: 001 / 011 | Total loss: 1.483 | Reg loss: 0.016 | Tree loss: 1.483 | Accuracy: 0.582500 | 0.377 sec/iter
# Epoch: 09 | Batch: 002 / 011 | Total loss: 1.439 | Reg loss: 0.016 | Tree loss: 1.439 | Accuracy: 0.587500 | 0.375 sec/iter
# Epoch: 09 | Batch: 003 / 011 | Total loss: 1.406 | Reg loss: 0.016 | Tree loss: 1.406 | Accuracy: 0.596000 | 0.373 sec/iter
# Epoch: 09 | Batch: 004 / 011 | Total loss: 1.369 | Reg loss: 0.016 | Tree loss: 1.369 | Accuracy: 0.610000 | 0.372 sec/iter
# Epoch: 09 | Batch: 005 / 011 | Total loss: 1.340 | Reg loss: 0.016 | Tree loss: 1.340 | Accuracy: 0.635500 | 0.37 sec/iter
# Epoch: 09 | Batch: 006 / 011 | Total loss: 1.314 | Reg loss: 0.017 | Tree loss: 1.314 | Accuracy: 0.663500 | 0.369 sec/iter
# Epoch: 09 | Batch: 007 / 011 | Total loss: 1.281 | Reg loss: 0.017 | Tree loss: 1.281 | Accuracy: 0.669500 | 0.367 sec/iter
# Epoch: 09 | Batch: 008 / 011 | Total loss: 1.266 | Reg loss: 0.017 | Tree loss: 1.266 | Accuracy: 0.676500 | 0.366 sec/iter
# Epoch: 09 | Batch: 009 / 011 | Total loss: 1.241 | Reg loss: 0.018 | Tree loss: 1.241 | Accuracy: 0.693500 | 0.364 sec/iter
# Epoch: 09 | Batch: 010 / 011 | Total loss: 1.272 | Reg loss: 0.018 | Tree loss: 1.272 | Accuracy: 0.672355 | 0.363 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 10 | Batch: 000 / 011 | Total loss: 1.472 | Reg loss: 0.016 | Tree loss: 1.472 | Accuracy: 0.581500 | 0.368 sec/iter
# Epoch: 10 | Batch: 001 / 011 | Total loss: 1.443 | Reg loss: 0.016 | Tree loss: 1.443 | Accuracy: 0.595000 | 0.367 sec/iter
# Epoch: 10 | Batch: 002 / 011 | Total loss: 1.399 | Reg loss: 0.016 | Tree loss: 1.399 | Accuracy: 0.591500 | 0.366 sec/iter
# Epoch: 10 | Batch: 003 / 011 | Total loss: 1.376 | Reg loss: 0.017 | Tree loss: 1.376 | Accuracy: 0.559000 | 0.364 sec/iter
# Epoch: 10 | Batch: 004 / 011 | Total loss: 1.324 | Reg loss: 0.017 | Tree loss: 1.324 | Accuracy: 0.575500 | 0.363 sec/iter
# Epoch: 10 | Batch: 005 / 011 | Total loss: 1.310 | Reg loss: 0.017 | Tree loss: 1.310 | Accuracy: 0.595500 | 0.362 sec/iter
# Epoch: 10 | Batch: 006 / 011 | Total loss: 1.257 | Reg loss: 0.017 | Tree loss: 1.257 | Accuracy: 0.668000 | 0.361 sec/iter
# Epoch: 10 | Batch: 007 / 011 | Total loss: 1.229 | Reg loss: 0.018 | Tree loss: 1.229 | Accuracy: 0.678000 | 0.359 sec/iter
# Epoch: 10 | Batch: 008 / 011 | Total loss: 1.211 | Reg loss: 0.018 | Tree loss: 1.211 | Accuracy: 0.696000 | 0.359 sec/iter
# Epoch: 10 | Batch: 009 / 011 | Total loss: 1.193 | Reg loss: 0.018 | Tree loss: 1.193 | Accuracy: 0.697500 | 0.357 sec/iter
# Epoch: 10 | Batch: 010 / 011 | Total loss: 1.196 | Reg loss: 0.018 | Tree loss: 1.196 | Accuracy: 0.709898 | 0.356 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 11 | Batch: 000 / 011 | Total loss: 1.433 | Reg loss: 0.017 | Tree loss: 1.433 | Accuracy: 0.594000 | 0.376 sec/iter
# Epoch: 11 | Batch: 001 / 011 | Total loss: 1.404 | Reg loss: 0.017 | Tree loss: 1.404 | Accuracy: 0.619000 | 0.374 sec/iter
# Epoch: 11 | Batch: 002 / 011 | Total loss: 1.357 | Reg loss: 0.017 | Tree loss: 1.357 | Accuracy: 0.616000 | 0.373 sec/iter
# Epoch: 11 | Batch: 003 / 011 | Total loss: 1.311 | Reg loss: 0.017 | Tree loss: 1.311 | Accuracy: 0.636000 | 0.372 sec/iter
# Epoch: 11 | Batch: 004 / 011 | Total loss: 1.278 | Reg loss: 0.017 | Tree loss: 1.278 | Accuracy: 0.657000 | 0.371 sec/iter
# Epoch: 11 | Batch: 005 / 011 | Total loss: 1.235 | Reg loss: 0.018 | Tree loss: 1.235 | Accuracy: 0.678000 | 0.37 sec/iter
# Epoch: 11 | Batch: 006 / 011 | Total loss: 1.228 | Reg loss: 0.018 | Tree loss: 1.228 | Accuracy: 0.656000 | 0.368 sec/iter
# Epoch: 11 | Batch: 007 / 011 | Total loss: 1.202 | Reg loss: 0.018 | Tree loss: 1.202 | Accuracy: 0.694000 | 0.367 sec/iter
# Epoch: 11 | Batch: 008 / 011 | Total loss: 1.160 | Reg loss: 0.018 | Tree loss: 1.160 | Accuracy: 0.722500 | 0.366 sec/iter
# Epoch: 11 | Batch: 009 / 011 | Total loss: 1.151 | Reg loss: 0.019 | Tree loss: 1.151 | Accuracy: 0.712500 | 0.366 sec/iter
# Epoch: 11 | Batch: 010 / 011 | Total loss: 1.145 | Reg loss: 0.019 | Tree loss: 1.145 | Accuracy: 0.733788 | 0.365 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 12 | Batch: 000 / 011 | Total loss: 1.391 | Reg loss: 0.017 | Tree loss: 1.391 | Accuracy: 0.611500 | 0.371 sec/iter
# Epoch: 12 | Batch: 001 / 011 | Total loss: 1.357 | Reg loss: 0.017 | Tree loss: 1.357 | Accuracy: 0.616000 | 0.37 sec/iter
# Epoch: 12 | Batch: 002 / 011 | Total loss: 1.320 | Reg loss: 0.018 | Tree loss: 1.320 | Accuracy: 0.608000 | 0.369 sec/iter
# Epoch: 12 | Batch: 003 / 011 | Total loss: 1.270 | Reg loss: 0.018 | Tree loss: 1.270 | Accuracy: 0.623500 | 0.367 sec/iter
# Epoch: 12 | Batch: 004 / 011 | Total loss: 1.230 | Reg loss: 0.018 | Tree loss: 1.230 | Accuracy: 0.618000 | 0.366 sec/iter
# Epoch: 12 | Batch: 005 / 011 | Total loss: 1.193 | Reg loss: 0.018 | Tree loss: 1.193 | Accuracy: 0.639500 | 0.365 sec/iter
# Epoch: 12 | Batch: 006 / 011 | Total loss: 1.193 | Reg loss: 0.018 | Tree loss: 1.193 | Accuracy: 0.676000 | 0.364 sec/iter
# Epoch: 12 | Batch: 007 / 011 | Total loss: 1.155 | Reg loss: 0.019 | Tree loss: 1.155 | Accuracy: 0.690000 | 0.363 sec/iter
# Epoch: 12 | Batch: 008 / 011 | Total loss: 1.122 | Reg loss: 0.019 | Tree loss: 1.122 | Accuracy: 0.705000 | 0.362 sec/iter
# Epoch: 12 | Batch: 009 / 011 | Total loss: 1.110 | Reg loss: 0.019 | Tree loss: 1.110 | Accuracy: 0.728000 | 0.361 sec/iter
# Epoch: 12 | Batch: 010 / 011 | Total loss: 1.101 | Reg loss: 0.019 | Tree loss: 1.101 | Accuracy: 0.747440 | 0.36 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 13 | Batch: 000 / 011 | Total loss: 1.348 | Reg loss: 0.018 | Tree loss: 1.348 | Accuracy: 0.648500 | 0.377 sec/iter
# Epoch: 13 | Batch: 001 / 011 | Total loss: 1.283 | Reg loss: 0.018 | Tree loss: 1.283 | Accuracy: 0.638000 | 0.376 sec/iter
# Epoch: 13 | Batch: 002 / 011 | Total loss: 1.272 | Reg loss: 0.018 | Tree loss: 1.272 | Accuracy: 0.622500 | 0.374 sec/iter
# Epoch: 13 | Batch: 003 / 011 | Total loss: 1.243 | Reg loss: 0.018 | Tree loss: 1.243 | Accuracy: 0.609500 | 0.373 sec/iter
# Epoch: 13 | Batch: 004 / 011 | Total loss: 1.196 | Reg loss: 0.018 | Tree loss: 1.196 | Accuracy: 0.664000 | 0.372 sec/iter
# Epoch: 13 | Batch: 005 / 011 | Total loss: 1.162 | Reg loss: 0.019 | Tree loss: 1.162 | Accuracy: 0.708500 | 0.371 sec/iter
# Epoch: 13 | Batch: 006 / 011 | Total loss: 1.129 | Reg loss: 0.019 | Tree loss: 1.129 | Accuracy: 0.724000 | 0.37 sec/iter
# Epoch: 13 | Batch: 007 / 011 | Total loss: 1.108 | Reg loss: 0.019 | Tree loss: 1.108 | Accuracy: 0.723000 | 0.369 sec/iter
# Epoch: 13 | Batch: 008 / 011 | Total loss: 1.092 | Reg loss: 0.019 | Tree loss: 1.092 | Accuracy: 0.736000 | 0.368 sec/iter
# Epoch: 13 | Batch: 009 / 011 | Total loss: 1.072 | Reg loss: 0.019 | Tree loss: 1.072 | Accuracy: 0.735000 | 0.367 sec/iter
# Epoch: 13 | Batch: 010 / 011 | Total loss: 1.031 | Reg loss: 0.020 | Tree loss: 1.031 | Accuracy: 0.737201 | 0.366 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 14 | Batch: 000 / 011 | Total loss: 1.304 | Reg loss: 0.018 | Tree loss: 1.304 | Accuracy: 0.627000 | 0.382 sec/iter
# Epoch: 14 | Batch: 001 / 011 | Total loss: 1.257 | Reg loss: 0.018 | Tree loss: 1.257 | Accuracy: 0.639500 | 0.381 sec/iter
# Epoch: 14 | Batch: 002 / 011 | Total loss: 1.229 | Reg loss: 0.019 | Tree loss: 1.229 | Accuracy: 0.613500 | 0.379 sec/iter
# Epoch: 14 | Batch: 003 / 011 | Total loss: 1.206 | Reg loss: 0.019 | Tree loss: 1.206 | Accuracy: 0.633500 | 0.378 sec/iter
# Epoch: 14 | Batch: 004 / 011 | Total loss: 1.174 | Reg loss: 0.019 | Tree loss: 1.174 | Accuracy: 0.679500 | 0.377 sec/iter
# Epoch: 14 | Batch: 005 / 011 | Total loss: 1.133 | Reg loss: 0.019 | Tree loss: 1.133 | Accuracy: 0.719500 | 0.376 sec/iter
# Epoch: 14 | Batch: 006 / 011 | Total loss: 1.099 | Reg loss: 0.019 | Tree loss: 1.099 | Accuracy: 0.719000 | 0.375 sec/iter
# Epoch: 14 | Batch: 007 / 011 | Total loss: 1.088 | Reg loss: 0.019 | Tree loss: 1.088 | Accuracy: 0.735000 | 0.374 sec/iter
# Epoch: 14 | Batch: 008 / 011 | Total loss: 1.037 | Reg loss: 0.020 | Tree loss: 1.037 | Accuracy: 0.746500 | 0.373 sec/iter
# Epoch: 14 | Batch: 009 / 011 | Total loss: 1.012 | Reg loss: 0.020 | Tree loss: 1.012 | Accuracy: 0.756000 | 0.372 sec/iter
# Epoch: 14 | Batch: 010 / 011 | Total loss: 0.973 | Reg loss: 0.020 | Tree loss: 0.973 | Accuracy: 0.788396 | 0.371 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 15 | Batch: 000 / 011 | Total loss: 1.270 | Reg loss: 0.019 | Tree loss: 1.270 | Accuracy: 0.608000 | 0.386 sec/iter
# Epoch: 15 | Batch: 001 / 011 | Total loss: 1.229 | Reg loss: 0.019 | Tree loss: 1.229 | Accuracy: 0.600000 | 0.384 sec/iter
# Epoch: 15 | Batch: 002 / 011 | Total loss: 1.196 | Reg loss: 0.019 | Tree loss: 1.196 | Accuracy: 0.614000 | 0.383 sec/iter
# Epoch: 15 | Batch: 003 / 011 | Total loss: 1.154 | Reg loss: 0.019 | Tree loss: 1.154 | Accuracy: 0.647500 | 0.382 sec/iter
# Epoch: 15 | Batch: 004 / 011 | Total loss: 1.097 | Reg loss: 0.019 | Tree loss: 1.097 | Accuracy: 0.704000 | 0.381 sec/iter
# Epoch: 15 | Batch: 005 / 011 | Total loss: 1.099 | Reg loss: 0.019 | Tree loss: 1.099 | Accuracy: 0.720000 | 0.381 sec/iter
# Epoch: 15 | Batch: 006 / 011 | Total loss: 1.055 | Reg loss: 0.020 | Tree loss: 1.055 | Accuracy: 0.751000 | 0.38 sec/iter
# Epoch: 15 | Batch: 007 / 011 | Total loss: 1.035 | Reg loss: 0.020 | Tree loss: 1.035 | Accuracy: 0.750500 | 0.379 sec/iter
# Epoch: 15 | Batch: 008 / 011 | Total loss: 1.028 | Reg loss: 0.020 | Tree loss: 1.028 | Accuracy: 0.750000 | 0.378 sec/iter
# Epoch: 15 | Batch: 009 / 011 | Total loss: 1.008 | Reg loss: 0.020 | Tree loss: 1.008 | Accuracy: 0.755000 | 0.377 sec/iter
# Epoch: 15 | Batch: 010 / 011 | Total loss: 1.015 | Reg loss: 0.020 | Tree loss: 1.015 | Accuracy: 0.744027 | 0.376 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 16 | Batch: 000 / 011 | Total loss: 1.242 | Reg loss: 0.019 | Tree loss: 1.242 | Accuracy: 0.599500 | 0.389 sec/iter
# Epoch: 16 | Batch: 001 / 011 | Total loss: 1.204 | Reg loss: 0.019 | Tree loss: 1.204 | Accuracy: 0.599500 | 0.388 sec/iter
# Epoch: 16 | Batch: 002 / 011 | Total loss: 1.152 | Reg loss: 0.019 | Tree loss: 1.152 | Accuracy: 0.642000 | 0.387 sec/iter
# Epoch: 16 | Batch: 003 / 011 | Total loss: 1.135 | Reg loss: 0.019 | Tree loss: 1.135 | Accuracy: 0.688500 | 0.386 sec/iter
# Epoch: 16 | Batch: 004 / 011 | Total loss: 1.079 | Reg loss: 0.020 | Tree loss: 1.079 | Accuracy: 0.744000 | 0.385 sec/iter
# Epoch: 16 | Batch: 005 / 011 | Total loss: 1.042 | Reg loss: 0.020 | Tree loss: 1.042 | Accuracy: 0.772500 | 0.384 sec/iter
# Epoch: 16 | Batch: 006 / 011 | Total loss: 1.014 | Reg loss: 0.020 | Tree loss: 1.014 | Accuracy: 0.764500 | 0.383 sec/iter
# Epoch: 16 | Batch: 007 / 011 | Total loss: 1.024 | Reg loss: 0.020 | Tree loss: 1.024 | Accuracy: 0.745000 | 0.382 sec/iter
# Epoch: 16 | Batch: 008 / 011 | Total loss: 0.979 | Reg loss: 0.020 | Tree loss: 0.979 | Accuracy: 0.786000 | 0.381 sec/iter
# Epoch: 16 | Batch: 009 / 011 | Total loss: 0.958 | Reg loss: 0.020 | Tree loss: 0.958 | Accuracy: 0.772000 | 0.381 sec/iter
# Epoch: 16 | Batch: 010 / 011 | Total loss: 0.940 | Reg loss: 0.021 | Tree loss: 0.940 | Accuracy: 0.726962 | 0.38 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 17 | Batch: 000 / 011 | Total loss: 1.203 | Reg loss: 0.020 | Tree loss: 1.203 | Accuracy: 0.592500 | 0.392 sec/iter
# Epoch: 17 | Batch: 001 / 011 | Total loss: 1.162 | Reg loss: 0.020 | Tree loss: 1.162 | Accuracy: 0.623500 | 0.391 sec/iter
# Epoch: 17 | Batch: 002 / 011 | Total loss: 1.132 | Reg loss: 0.020 | Tree loss: 1.132 | Accuracy: 0.637500 | 0.39 sec/iter
# Epoch: 17 | Batch: 003 / 011 | Total loss: 1.071 | Reg loss: 0.020 | Tree loss: 1.071 | Accuracy: 0.704500 | 0.389 sec/iter
# Epoch: 17 | Batch: 004 / 011 | Total loss: 1.051 | Reg loss: 0.020 | Tree loss: 1.051 | Accuracy: 0.737000 | 0.389 sec/iter
# Epoch: 17 | Batch: 005 / 011 | Total loss: 1.022 | Reg loss: 0.020 | Tree loss: 1.022 | Accuracy: 0.765000 | 0.388 sec/iter
# Epoch: 17 | Batch: 006 / 011 | Total loss: 1.000 | Reg loss: 0.020 | Tree loss: 1.000 | Accuracy: 0.781500 | 0.387 sec/iter
# Epoch: 17 | Batch: 007 / 011 | Total loss: 0.974 | Reg loss: 0.020 | Tree loss: 0.974 | Accuracy: 0.777000 | 0.386 sec/iter
# Epoch: 17 | Batch: 008 / 011 | Total loss: 0.947 | Reg loss: 0.020 | Tree loss: 0.947 | Accuracy: 0.785500 | 0.385 sec/iter
# Epoch: 17 | Batch: 009 / 011 | Total loss: 0.948 | Reg loss: 0.021 | Tree loss: 0.948 | Accuracy: 0.772500 | 0.384 sec/iter
# Epoch: 17 | Batch: 010 / 011 | Total loss: 0.943 | Reg loss: 0.021 | Tree loss: 0.943 | Accuracy: 0.744027 | 0.383 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 18 | Batch: 000 / 011 | Total loss: 1.146 | Reg loss: 0.020 | Tree loss: 1.146 | Accuracy: 0.627000 | 0.395 sec/iter
# Epoch: 18 | Batch: 001 / 011 | Total loss: 1.122 | Reg loss: 0.020 | Tree loss: 1.122 | Accuracy: 0.615000 | 0.394 sec/iter
# Epoch: 18 | Batch: 002 / 011 | Total loss: 1.084 | Reg loss: 0.020 | Tree loss: 1.084 | Accuracy: 0.659500 | 0.393 sec/iter
# Epoch: 18 | Batch: 003 / 011 | Total loss: 1.048 | Reg loss: 0.020 | Tree loss: 1.048 | Accuracy: 0.703000 | 0.393 sec/iter
# Epoch: 18 | Batch: 004 / 011 | Total loss: 1.028 | Reg loss: 0.020 | Tree loss: 1.028 | Accuracy: 0.756500 | 0.392 sec/iter
# Epoch: 18 | Batch: 005 / 011 | Total loss: 1.016 | Reg loss: 0.020 | Tree loss: 1.016 | Accuracy: 0.773500 | 0.391 sec/iter
# Epoch: 18 | Batch: 006 / 011 | Total loss: 0.976 | Reg loss: 0.020 | Tree loss: 0.976 | Accuracy: 0.777000 | 0.39 sec/iter
# Epoch: 18 | Batch: 007 / 011 | Total loss: 0.941 | Reg loss: 0.021 | Tree loss: 0.941 | Accuracy: 0.772000 | 0.389 sec/iter
# Epoch: 18 | Batch: 008 / 011 | Total loss: 0.942 | Reg loss: 0.021 | Tree loss: 0.942 | Accuracy: 0.772500 | 0.388 sec/iter
# Epoch: 18 | Batch: 009 / 011 | Total loss: 0.925 | Reg loss: 0.021 | Tree loss: 0.925 | Accuracy: 0.787000 | 0.387 sec/iter
# Epoch: 18 | Batch: 010 / 011 | Total loss: 0.909 | Reg loss: 0.021 | Tree loss: 0.909 | Accuracy: 0.784983 | 0.386 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 19 | Batch: 000 / 011 | Total loss: 1.132 | Reg loss: 0.020 | Tree loss: 1.132 | Accuracy: 0.604000 | 0.386 sec/iter
# Epoch: 19 | Batch: 001 / 011 | Total loss: 1.109 | Reg loss: 0.020 | Tree loss: 1.109 | Accuracy: 0.607000 | 0.385 sec/iter
# Epoch: 19 | Batch: 002 / 011 | Total loss: 1.063 | Reg loss: 0.020 | Tree loss: 1.063 | Accuracy: 0.652500 | 0.384 sec/iter
# Epoch: 19 | Batch: 003 / 011 | Total loss: 1.038 | Reg loss: 0.020 | Tree loss: 1.038 | Accuracy: 0.704000 | 0.384 sec/iter
# Epoch: 19 | Batch: 004 / 011 | Total loss: 0.993 | Reg loss: 0.020 | Tree loss: 0.993 | Accuracy: 0.776000 | 0.383 sec/iter
# Epoch: 19 | Batch: 005 / 011 | Total loss: 0.966 | Reg loss: 0.021 | Tree loss: 0.966 | Accuracy: 0.784000 | 0.382 sec/iter
# Epoch: 19 | Batch: 006 / 011 | Total loss: 0.941 | Reg loss: 0.021 | Tree loss: 0.941 | Accuracy: 0.796000 | 0.381 sec/iter
# Epoch: 19 | Batch: 007 / 011 | Total loss: 0.938 | Reg loss: 0.021 | Tree loss: 0.938 | Accuracy: 0.780000 | 0.381 sec/iter
# Epoch: 19 | Batch: 008 / 011 | Total loss: 0.902 | Reg loss: 0.021 | Tree loss: 0.902 | Accuracy: 0.788000 | 0.38 sec/iter
# Epoch: 19 | Batch: 009 / 011 | Total loss: 0.885 | Reg loss: 0.021 | Tree loss: 0.885 | Accuracy: 0.793500 | 0.379 sec/iter
# Epoch: 19 | Batch: 010 / 011 | Total loss: 0.909 | Reg loss: 0.021 | Tree loss: 0.909 | Accuracy: 0.757679 | 0.378 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 20 | Batch: 000 / 011 | Total loss: 1.091 | Reg loss: 0.020 | Tree loss: 1.091 | Accuracy: 0.624500 | 0.389 sec/iter
# Epoch: 20 | Batch: 001 / 011 | Total loss: 1.066 | Reg loss: 0.021 | Tree loss: 1.066 | Accuracy: 0.613500 | 0.388 sec/iter
# Epoch: 20 | Batch: 002 / 011 | Total loss: 1.026 | Reg loss: 0.021 | Tree loss: 1.026 | Accuracy: 0.648500 | 0.388 sec/iter
# Epoch: 20 | Batch: 003 / 011 | Total loss: 1.008 | Reg loss: 0.021 | Tree loss: 1.008 | Accuracy: 0.680000 | 0.387 sec/iter
# Epoch: 20 | Batch: 004 / 011 | Total loss: 0.980 | Reg loss: 0.021 | Tree loss: 0.980 | Accuracy: 0.750500 | 0.386 sec/iter
# Epoch: 20 | Batch: 005 / 011 | Total loss: 0.959 | Reg loss: 0.021 | Tree loss: 0.959 | Accuracy: 0.778500 | 0.385 sec/iter
# Epoch: 20 | Batch: 006 / 011 | Total loss: 0.925 | Reg loss: 0.021 | Tree loss: 0.925 | Accuracy: 0.784000 | 0.385 sec/iter
# Epoch: 20 | Batch: 007 / 011 | Total loss: 0.914 | Reg loss: 0.021 | Tree loss: 0.914 | Accuracy: 0.785000 | 0.384 sec/iter
# Epoch: 20 | Batch: 008 / 011 | Total loss: 0.902 | Reg loss: 0.021 | Tree loss: 0.902 | Accuracy: 0.767500 | 0.383 sec/iter
# Epoch: 20 | Batch: 009 / 011 | Total loss: 0.888 | Reg loss: 0.021 | Tree loss: 0.888 | Accuracy: 0.792000 | 0.383 sec/iter
# Epoch: 20 | Batch: 010 / 011 | Total loss: 0.844 | Reg loss: 0.021 | Tree loss: 0.844 | Accuracy: 0.839590 | 0.382 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 21 | Batch: 000 / 011 | Total loss: 1.090 | Reg loss: 0.021 | Tree loss: 1.090 | Accuracy: 0.590500 | 0.389 sec/iter
# Epoch: 21 | Batch: 001 / 011 | Total loss: 1.050 | Reg loss: 0.021 | Tree loss: 1.050 | Accuracy: 0.625000 | 0.388 sec/iter
# Epoch: 21 | Batch: 002 / 011 | Total loss: 1.028 | Reg loss: 0.021 | Tree loss: 1.028 | Accuracy: 0.649000 | 0.387 sec/iter
# Epoch: 21 | Batch: 003 / 011 | Total loss: 0.994 | Reg loss: 0.021 | Tree loss: 0.994 | Accuracy: 0.697000 | 0.387 sec/iter
# Epoch: 21 | Batch: 004 / 011 | Total loss: 0.937 | Reg loss: 0.021 | Tree loss: 0.937 | Accuracy: 0.757000 | 0.386 sec/iter
# Epoch: 21 | Batch: 005 / 011 | Total loss: 0.927 | Reg loss: 0.021 | Tree loss: 0.927 | Accuracy: 0.779500 | 0.385 sec/iter
# Epoch: 21 | Batch: 006 / 011 | Total loss: 0.909 | Reg loss: 0.021 | Tree loss: 0.909 | Accuracy: 0.787000 | 0.384 sec/iter
# Epoch: 21 | Batch: 007 / 011 | Total loss: 0.900 | Reg loss: 0.021 | Tree loss: 0.900 | Accuracy: 0.785500 | 0.384 sec/iter
# Epoch: 21 | Batch: 008 / 011 | Total loss: 0.862 | Reg loss: 0.021 | Tree loss: 0.862 | Accuracy: 0.800500 | 0.383 sec/iter
# Epoch: 21 | Batch: 009 / 011 | Total loss: 0.849 | Reg loss: 0.022 | Tree loss: 0.849 | Accuracy: 0.807000 | 0.382 sec/iter
# Epoch: 21 | Batch: 010 / 011 | Total loss: 0.833 | Reg loss: 0.022 | Tree loss: 0.833 | Accuracy: 0.795222 | 0.382 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 22 | Batch: 000 / 011 | Total loss: 1.040 | Reg loss: 0.021 | Tree loss: 1.040 | Accuracy: 0.626500 | 0.391 sec/iter
# Epoch: 22 | Batch: 001 / 011 | Total loss: 1.020 | Reg loss: 0.021 | Tree loss: 1.020 | Accuracy: 0.649000 | 0.391 sec/iter
# Epoch: 22 | Batch: 002 / 011 | Total loss: 0.998 | Reg loss: 0.021 | Tree loss: 0.998 | Accuracy: 0.663000 | 0.39 sec/iter
# Epoch: 22 | Batch: 003 / 011 | Total loss: 0.968 | Reg loss: 0.021 | Tree loss: 0.968 | Accuracy: 0.708000 | 0.389 sec/iter
# Epoch: 22 | Batch: 004 / 011 | Total loss: 0.935 | Reg loss: 0.021 | Tree loss: 0.935 | Accuracy: 0.763000 | 0.389 sec/iter
# Epoch: 22 | Batch: 005 / 011 | Total loss: 0.912 | Reg loss: 0.021 | Tree loss: 0.912 | Accuracy: 0.777000 | 0.388 sec/iter
# Epoch: 22 | Batch: 006 / 011 | Total loss: 0.877 | Reg loss: 0.021 | Tree loss: 0.877 | Accuracy: 0.795000 | 0.387 sec/iter
# Epoch: 22 | Batch: 007 / 011 | Total loss: 0.861 | Reg loss: 0.021 | Tree loss: 0.861 | Accuracy: 0.795500 | 0.387 sec/iter
# Epoch: 22 | Batch: 008 / 011 | Total loss: 0.872 | Reg loss: 0.022 | Tree loss: 0.872 | Accuracy: 0.784500 | 0.386 sec/iter
# Epoch: 22 | Batch: 009 / 011 | Total loss: 0.855 | Reg loss: 0.022 | Tree loss: 0.855 | Accuracy: 0.804500 | 0.385 sec/iter
# Epoch: 22 | Batch: 010 / 011 | Total loss: 0.835 | Reg loss: 0.022 | Tree loss: 0.835 | Accuracy: 0.805461 | 0.385 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 23 | Batch: 000 / 011 | Total loss: 1.029 | Reg loss: 0.021 | Tree loss: 1.029 | Accuracy: 0.623500 | 0.394 sec/iter
# Epoch: 23 | Batch: 001 / 011 | Total loss: 0.988 | Reg loss: 0.021 | Tree loss: 0.988 | Accuracy: 0.647000 | 0.393 sec/iter
# Epoch: 23 | Batch: 002 / 011 | Total loss: 0.960 | Reg loss: 0.021 | Tree loss: 0.960 | Accuracy: 0.683000 | 0.392 sec/iter
# Epoch: 23 | Batch: 003 / 011 | Total loss: 0.941 | Reg loss: 0.021 | Tree loss: 0.941 | Accuracy: 0.720000 | 0.392 sec/iter
# Epoch: 23 | Batch: 004 / 011 | Total loss: 0.941 | Reg loss: 0.021 | Tree loss: 0.941 | Accuracy: 0.750000 | 0.391 sec/iter
# Epoch: 23 | Batch: 005 / 011 | Total loss: 0.879 | Reg loss: 0.021 | Tree loss: 0.879 | Accuracy: 0.803000 | 0.39 sec/iter
# Epoch: 23 | Batch: 006 / 011 | Total loss: 0.868 | Reg loss: 0.022 | Tree loss: 0.868 | Accuracy: 0.793000 | 0.39 sec/iter
# Epoch: 23 | Batch: 007 / 011 | Total loss: 0.864 | Reg loss: 0.022 | Tree loss: 0.864 | Accuracy: 0.807000 | 0.389 sec/iter
# Epoch: 23 | Batch: 008 / 011 | Total loss: 0.843 | Reg loss: 0.022 | Tree loss: 0.843 | Accuracy: 0.796500 | 0.388 sec/iter
# Epoch: 23 | Batch: 009 / 011 | Total loss: 0.838 | Reg loss: 0.022 | Tree loss: 0.838 | Accuracy: 0.809500 | 0.388 sec/iter
# Epoch: 23 | Batch: 010 / 011 | Total loss: 0.856 | Reg loss: 0.022 | Tree loss: 0.856 | Accuracy: 0.771331 | 0.387 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 24 | Batch: 000 / 011 | Total loss: 0.994 | Reg loss: 0.021 | Tree loss: 0.994 | Accuracy: 0.654000 | 0.396 sec/iter
# Epoch: 24 | Batch: 001 / 011 | Total loss: 0.987 | Reg loss: 0.021 | Tree loss: 0.987 | Accuracy: 0.652000 | 0.395 sec/iter
# Epoch: 24 | Batch: 002 / 011 | Total loss: 0.965 | Reg loss: 0.021 | Tree loss: 0.965 | Accuracy: 0.676000 | 0.394 sec/iter
# Epoch: 24 | Batch: 003 / 011 | Total loss: 0.928 | Reg loss: 0.021 | Tree loss: 0.928 | Accuracy: 0.721000 | 0.394 sec/iter
# Epoch: 24 | Batch: 004 / 011 | Total loss: 0.880 | Reg loss: 0.022 | Tree loss: 0.880 | Accuracy: 0.786000 | 0.393 sec/iter
# Epoch: 24 | Batch: 005 / 011 | Total loss: 0.880 | Reg loss: 0.022 | Tree loss: 0.880 | Accuracy: 0.787000 | 0.392 sec/iter
# Epoch: 24 | Batch: 006 / 011 | Total loss: 0.873 | Reg loss: 0.022 | Tree loss: 0.873 | Accuracy: 0.791000 | 0.392 sec/iter
# Epoch: 24 | Batch: 007 / 011 | Total loss: 0.841 | Reg loss: 0.022 | Tree loss: 0.841 | Accuracy: 0.807000 | 0.391 sec/iter
# Epoch: 24 | Batch: 008 / 011 | Total loss: 0.839 | Reg loss: 0.022 | Tree loss: 0.839 | Accuracy: 0.802500 | 0.391 sec/iter
# Epoch: 24 | Batch: 009 / 011 | Total loss: 0.819 | Reg loss: 0.022 | Tree loss: 0.819 | Accuracy: 0.817000 | 0.39 sec/iter
# Epoch: 24 | Batch: 010 / 011 | Total loss: 0.832 | Reg loss: 0.022 | Tree loss: 0.832 | Accuracy: 0.795222 | 0.389 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 25 | Batch: 000 / 011 | Total loss: 1.008 | Reg loss: 0.022 | Tree loss: 1.008 | Accuracy: 0.660000 | 0.398 sec/iter
# Epoch: 25 | Batch: 001 / 011 | Total loss: 0.978 | Reg loss: 0.022 | Tree loss: 0.978 | Accuracy: 0.650500 | 0.397 sec/iter
# Epoch: 25 | Batch: 002 / 011 | Total loss: 0.949 | Reg loss: 0.022 | Tree loss: 0.949 | Accuracy: 0.684500 | 0.396 sec/iter
# Epoch: 25 | Batch: 003 / 011 | Total loss: 0.899 | Reg loss: 0.022 | Tree loss: 0.899 | Accuracy: 0.739500 | 0.396 sec/iter
# Epoch: 25 | Batch: 004 / 011 | Total loss: 0.871 | Reg loss: 0.022 | Tree loss: 0.871 | Accuracy: 0.778500 | 0.395 sec/iter
# Epoch: 25 | Batch: 005 / 011 | Total loss: 0.855 | Reg loss: 0.022 | Tree loss: 0.855 | Accuracy: 0.825500 | 0.394 sec/iter
# Epoch: 25 | Batch: 006 / 011 | Total loss: 0.832 | Reg loss: 0.022 | Tree loss: 0.832 | Accuracy: 0.806500 | 0.394 sec/iter
# Epoch: 25 | Batch: 007 / 011 | Total loss: 0.822 | Reg loss: 0.022 | Tree loss: 0.822 | Accuracy: 0.812000 | 0.393 sec/iter
# Epoch: 25 | Batch: 008 / 011 | Total loss: 0.820 | Reg loss: 0.022 | Tree loss: 0.820 | Accuracy: 0.811500 | 0.392 sec/iter
# Epoch: 25 | Batch: 009 / 011 | Total loss: 0.793 | Reg loss: 0.022 | Tree loss: 0.793 | Accuracy: 0.821500 | 0.392 sec/iter
# Epoch: 25 | Batch: 010 / 011 | Total loss: 0.842 | Reg loss: 0.022 | Tree loss: 0.842 | Accuracy: 0.812287 | 0.391 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 26 | Batch: 000 / 011 | Total loss: 1.014 | Reg loss: 0.022 | Tree loss: 1.014 | Accuracy: 0.647500 | 0.39 sec/iter
# Epoch: 26 | Batch: 001 / 011 | Total loss: 0.949 | Reg loss: 0.022 | Tree loss: 0.949 | Accuracy: 0.664000 | 0.39 sec/iter
# Epoch: 26 | Batch: 002 / 011 | Total loss: 0.910 | Reg loss: 0.022 | Tree loss: 0.910 | Accuracy: 0.717000 | 0.389 sec/iter
# Epoch: 26 | Batch: 003 / 011 | Total loss: 0.875 | Reg loss: 0.022 | Tree loss: 0.875 | Accuracy: 0.768500 | 0.389 sec/iter
# Epoch: 26 | Batch: 004 / 011 | Total loss: 0.864 | Reg loss: 0.022 | Tree loss: 0.864 | Accuracy: 0.793000 | 0.388 sec/iter
# Epoch: 26 | Batch: 005 / 011 | Total loss: 0.822 | Reg loss: 0.022 | Tree loss: 0.822 | Accuracy: 0.811000 | 0.387 sec/iter
# Epoch: 26 | Batch: 006 / 011 | Total loss: 0.817 | Reg loss: 0.022 | Tree loss: 0.817 | Accuracy: 0.811000 | 0.387 sec/iter
# Epoch: 26 | Batch: 007 / 011 | Total loss: 0.810 | Reg loss: 0.022 | Tree loss: 0.810 | Accuracy: 0.820000 | 0.386 sec/iter
# Epoch: 26 | Batch: 008 / 011 | Total loss: 0.821 | Reg loss: 0.022 | Tree loss: 0.821 | Accuracy: 0.807500 | 0.386 sec/iter
# Epoch: 26 | Batch: 009 / 011 | Total loss: 0.793 | Reg loss: 0.022 | Tree loss: 0.793 | Accuracy: 0.825000 | 0.385 sec/iter
# Epoch: 26 | Batch: 010 / 011 | Total loss: 0.757 | Reg loss: 0.022 | Tree loss: 0.757 | Accuracy: 0.846416 | 0.384 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 27 | Batch: 000 / 011 | Total loss: 0.963 | Reg loss: 0.022 | Tree loss: 0.963 | Accuracy: 0.667000 | 0.392 sec/iter
# Epoch: 27 | Batch: 001 / 011 | Total loss: 0.962 | Reg loss: 0.022 | Tree loss: 0.962 | Accuracy: 0.669000 | 0.392 sec/iter
# Epoch: 27 | Batch: 002 / 011 | Total loss: 0.899 | Reg loss: 0.022 | Tree loss: 0.899 | Accuracy: 0.724500 | 0.391 sec/iter
# Epoch: 27 | Batch: 003 / 011 | Total loss: 0.867 | Reg loss: 0.022 | Tree loss: 0.867 | Accuracy: 0.780000 | 0.39 sec/iter
# Epoch: 27 | Batch: 004 / 011 | Total loss: 0.856 | Reg loss: 0.022 | Tree loss: 0.856 | Accuracy: 0.794500 | 0.39 sec/iter
# Epoch: 27 | Batch: 005 / 011 | Total loss: 0.814 | Reg loss: 0.022 | Tree loss: 0.814 | Accuracy: 0.821000 | 0.389 sec/iter
# Epoch: 27 | Batch: 006 / 011 | Total loss: 0.817 | Reg loss: 0.022 | Tree loss: 0.817 | Accuracy: 0.817000 | 0.389 sec/iter
# Epoch: 27 | Batch: 007 / 011 | Total loss: 0.799 | Reg loss: 0.022 | Tree loss: 0.799 | Accuracy: 0.826000 | 0.388 sec/iter
# Epoch: 27 | Batch: 008 / 011 | Total loss: 0.788 | Reg loss: 0.022 | Tree loss: 0.788 | Accuracy: 0.825500 | 0.388 sec/iter
# Epoch: 27 | Batch: 009 / 011 | Total loss: 0.769 | Reg loss: 0.022 | Tree loss: 0.769 | Accuracy: 0.828000 | 0.387 sec/iter
# Epoch: 27 | Batch: 010 / 011 | Total loss: 0.738 | Reg loss: 0.022 | Tree loss: 0.738 | Accuracy: 0.832765 | 0.386 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 28 | Batch: 000 / 011 | Total loss: 0.950 | Reg loss: 0.022 | Tree loss: 0.950 | Accuracy: 0.675000 | 0.393 sec/iter
# Epoch: 28 | Batch: 001 / 011 | Total loss: 0.917 | Reg loss: 0.022 | Tree loss: 0.917 | Accuracy: 0.698000 | 0.392 sec/iter
# Epoch: 28 | Batch: 002 / 011 | Total loss: 0.886 | Reg loss: 0.022 | Tree loss: 0.886 | Accuracy: 0.735000 | 0.391 sec/iter
# Epoch: 28 | Batch: 003 / 011 | Total loss: 0.855 | Reg loss: 0.022 | Tree loss: 0.855 | Accuracy: 0.755500 | 0.391 sec/iter
# Epoch: 28 | Batch: 004 / 011 | Total loss: 0.809 | Reg loss: 0.022 | Tree loss: 0.809 | Accuracy: 0.815000 | 0.39 sec/iter
# Epoch: 28 | Batch: 005 / 011 | Total loss: 0.822 | Reg loss: 0.022 | Tree loss: 0.822 | Accuracy: 0.806000 | 0.39 sec/iter
# Epoch: 28 | Batch: 006 / 011 | Total loss: 0.793 | Reg loss: 0.022 | Tree loss: 0.793 | Accuracy: 0.815000 | 0.389 sec/iter
# Epoch: 28 | Batch: 007 / 011 | Total loss: 0.765 | Reg loss: 0.022 | Tree loss: 0.765 | Accuracy: 0.831000 | 0.388 sec/iter
# Epoch: 28 | Batch: 008 / 011 | Total loss: 0.781 | Reg loss: 0.022 | Tree loss: 0.781 | Accuracy: 0.832500 | 0.388 sec/iter
# Epoch: 28 | Batch: 009 / 011 | Total loss: 0.786 | Reg loss: 0.023 | Tree loss: 0.786 | Accuracy: 0.815500 | 0.387 sec/iter
# Epoch: 28 | Batch: 010 / 011 | Total loss: 0.755 | Reg loss: 0.023 | Tree loss: 0.755 | Accuracy: 0.860068 | 0.387 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 29 | Batch: 000 / 011 | Total loss: 0.934 | Reg loss: 0.022 | Tree loss: 0.934 | Accuracy: 0.681000 | 0.394 sec/iter
# Epoch: 29 | Batch: 001 / 011 | Total loss: 0.889 | Reg loss: 0.022 | Tree loss: 0.889 | Accuracy: 0.717500 | 0.394 sec/iter
# Epoch: 29 | Batch: 002 / 011 | Total loss: 0.862 | Reg loss: 0.022 | Tree loss: 0.862 | Accuracy: 0.745500 | 0.393 sec/iter
# Epoch: 29 | Batch: 003 / 011 | Total loss: 0.850 | Reg loss: 0.022 | Tree loss: 0.850 | Accuracy: 0.785000 | 0.392 sec/iter
# Epoch: 29 | Batch: 004 / 011 | Total loss: 0.817 | Reg loss: 0.022 | Tree loss: 0.817 | Accuracy: 0.819500 | 0.392 sec/iter
# Epoch: 29 | Batch: 005 / 011 | Total loss: 0.801 | Reg loss: 0.022 | Tree loss: 0.801 | Accuracy: 0.821500 | 0.391 sec/iter
# Epoch: 29 | Batch: 006 / 011 | Total loss: 0.785 | Reg loss: 0.022 | Tree loss: 0.785 | Accuracy: 0.812500 | 0.391 sec/iter
# Epoch: 29 | Batch: 007 / 011 | Total loss: 0.758 | Reg loss: 0.022 | Tree loss: 0.758 | Accuracy: 0.825500 | 0.39 sec/iter
# Epoch: 29 | Batch: 008 / 011 | Total loss: 0.772 | Reg loss: 0.023 | Tree loss: 0.772 | Accuracy: 0.822000 | 0.39 sec/iter
# Epoch: 29 | Batch: 009 / 011 | Total loss: 0.762 | Reg loss: 0.023 | Tree loss: 0.762 | Accuracy: 0.824000 | 0.389 sec/iter
# Epoch: 29 | Batch: 010 / 011 | Total loss: 0.723 | Reg loss: 0.023 | Tree loss: 0.723 | Accuracy: 0.863481 | 0.389 sec/iter
# Average sparseness: 0.9723756906077348
# ...
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 490 | Batch: 000 / 011 | Total loss: 0.565 | Reg loss: 0.025 | Tree loss: 0.565 | Accuracy: 0.817500 | 0.375 sec/iter
# Epoch: 490 | Batch: 001 / 011 | Total loss: 0.551 | Reg loss: 0.025 | Tree loss: 0.551 | Accuracy: 0.823000 | 0.375 sec/iter
# Epoch: 490 | Batch: 002 / 011 | Total loss: 0.572 | Reg loss: 0.025 | Tree loss: 0.572 | Accuracy: 0.791000 | 0.375 sec/iter
# Epoch: 490 | Batch: 003 / 011 | Total loss: 0.509 | Reg loss: 0.025 | Tree loss: 0.509 | Accuracy: 0.828000 | 0.375 sec/iter
# Epoch: 490 | Batch: 004 / 011 | Total loss: 0.505 | Reg loss: 0.025 | Tree loss: 0.505 | Accuracy: 0.823000 | 0.375 sec/iter
# Epoch: 490 | Batch: 005 / 011 | Total loss: 0.471 | Reg loss: 0.025 | Tree loss: 0.471 | Accuracy: 0.852000 | 0.375 sec/iter
# Epoch: 490 | Batch: 006 / 011 | Total loss: 0.486 | Reg loss: 0.025 | Tree loss: 0.486 | Accuracy: 0.844000 | 0.375 sec/iter
# Epoch: 490 | Batch: 007 / 011 | Total loss: 0.469 | Reg loss: 0.025 | Tree loss: 0.469 | Accuracy: 0.856000 | 0.375 sec/iter
# Epoch: 490 | Batch: 008 / 011 | Total loss: 0.475 | Reg loss: 0.025 | Tree loss: 0.475 | Accuracy: 0.864000 | 0.374 sec/iter
# Epoch: 490 | Batch: 009 / 011 | Total loss: 0.459 | Reg loss: 0.025 | Tree loss: 0.459 | Accuracy: 0.873500 | 0.374 sec/iter
# Epoch: 490 | Batch: 010 / 011 | Total loss: 0.457 | Reg loss: 0.025 | Tree loss: 0.457 | Accuracy: 0.846416 | 0.374 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 491 | Batch: 000 / 011 | Total loss: 0.564 | Reg loss: 0.025 | Tree loss: 0.564 | Accuracy: 0.817500 | 0.375 sec/iter
# Epoch: 491 | Batch: 001 / 011 | Total loss: 0.551 | Reg loss: 0.025 | Tree loss: 0.551 | Accuracy: 0.824000 | 0.375 sec/iter
# Epoch: 491 | Batch: 002 / 011 | Total loss: 0.531 | Reg loss: 0.025 | Tree loss: 0.531 | Accuracy: 0.817000 | 0.375 sec/iter
# Epoch: 491 | Batch: 003 / 011 | Total loss: 0.525 | Reg loss: 0.025 | Tree loss: 0.525 | Accuracy: 0.828000 | 0.375 sec/iter
# Epoch: 491 | Batch: 004 / 011 | Total loss: 0.504 | Reg loss: 0.025 | Tree loss: 0.504 | Accuracy: 0.831000 | 0.375 sec/iter
# Epoch: 491 | Batch: 005 / 011 | Total loss: 0.497 | Reg loss: 0.025 | Tree loss: 0.497 | Accuracy: 0.842500 | 0.375 sec/iter
# Epoch: 491 | Batch: 006 / 011 | Total loss: 0.496 | Reg loss: 0.025 | Tree loss: 0.496 | Accuracy: 0.842500 | 0.375 sec/iter
# Epoch: 491 | Batch: 007 / 011 | Total loss: 0.462 | Reg loss: 0.025 | Tree loss: 0.462 | Accuracy: 0.860000 | 0.375 sec/iter
# Epoch: 491 | Batch: 008 / 011 | Total loss: 0.475 | Reg loss: 0.025 | Tree loss: 0.475 | Accuracy: 0.852500 | 0.375 sec/iter
# Epoch: 491 | Batch: 009 / 011 | Total loss: 0.445 | Reg loss: 0.025 | Tree loss: 0.445 | Accuracy: 0.872000 | 0.375 sec/iter
# Epoch: 491 | Batch: 010 / 011 | Total loss: 0.446 | Reg loss: 0.025 | Tree loss: 0.446 | Accuracy: 0.856655 | 0.374 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 492 | Batch: 000 / 011 | Total loss: 0.581 | Reg loss: 0.025 | Tree loss: 0.581 | Accuracy: 0.821000 | 0.375 sec/iter
# Epoch: 492 | Batch: 001 / 011 | Total loss: 0.588 | Reg loss: 0.025 | Tree loss: 0.588 | Accuracy: 0.794000 | 0.375 sec/iter
# Epoch: 492 | Batch: 002 / 011 | Total loss: 0.541 | Reg loss: 0.025 | Tree loss: 0.541 | Accuracy: 0.813000 | 0.375 sec/iter
# Epoch: 492 | Batch: 003 / 011 | Total loss: 0.523 | Reg loss: 0.025 | Tree loss: 0.523 | Accuracy: 0.822000 | 0.375 sec/iter
# Epoch: 492 | Batch: 004 / 011 | Total loss: 0.479 | Reg loss: 0.025 | Tree loss: 0.479 | Accuracy: 0.853000 | 0.375 sec/iter
# Epoch: 492 | Batch: 005 / 011 | Total loss: 0.483 | Reg loss: 0.025 | Tree loss: 0.483 | Accuracy: 0.847500 | 0.375 sec/iter
# Epoch: 492 | Batch: 006 / 011 | Total loss: 0.475 | Reg loss: 0.025 | Tree loss: 0.475 | Accuracy: 0.852000 | 0.375 sec/iter
# Epoch: 492 | Batch: 007 / 011 | Total loss: 0.458 | Reg loss: 0.025 | Tree loss: 0.458 | Accuracy: 0.869500 | 0.375 sec/iter
# Epoch: 492 | Batch: 008 / 011 | Total loss: 0.470 | Reg loss: 0.025 | Tree loss: 0.470 | Accuracy: 0.856000 | 0.375 sec/iter
# Epoch: 492 | Batch: 009 / 011 | Total loss: 0.451 | Reg loss: 0.025 | Tree loss: 0.451 | Accuracy: 0.873500 | 0.375 sec/iter
# Epoch: 492 | Batch: 010 / 011 | Total loss: 0.477 | Reg loss: 0.025 | Tree loss: 0.477 | Accuracy: 0.877133 | 0.375 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 493 | Batch: 000 / 011 | Total loss: 0.589 | Reg loss: 0.025 | Tree loss: 0.589 | Accuracy: 0.823500 | 0.375 sec/iter
# Epoch: 493 | Batch: 001 / 011 | Total loss: 0.565 | Reg loss: 0.025 | Tree loss: 0.565 | Accuracy: 0.814000 | 0.375 sec/iter
# Epoch: 493 | Batch: 002 / 011 | Total loss: 0.536 | Reg loss: 0.025 | Tree loss: 0.536 | Accuracy: 0.820000 | 0.375 sec/iter
# Epoch: 493 | Batch: 003 / 011 | Total loss: 0.517 | Reg loss: 0.025 | Tree loss: 0.517 | Accuracy: 0.823500 | 0.375 sec/iter
# Epoch: 493 | Batch: 004 / 011 | Total loss: 0.497 | Reg loss: 0.025 | Tree loss: 0.497 | Accuracy: 0.831500 | 0.375 sec/iter
# Epoch: 493 | Batch: 005 / 011 | Total loss: 0.504 | Reg loss: 0.025 | Tree loss: 0.504 | Accuracy: 0.830500 | 0.375 sec/iter
# Epoch: 493 | Batch: 006 / 011 | Total loss: 0.482 | Reg loss: 0.025 | Tree loss: 0.482 | Accuracy: 0.850500 | 0.375 sec/iter
# Epoch: 493 | Batch: 007 / 011 | Total loss: 0.471 | Reg loss: 0.025 | Tree loss: 0.471 | Accuracy: 0.857500 | 0.375 sec/iter
# Epoch: 493 | Batch: 008 / 011 | Total loss: 0.451 | Reg loss: 0.025 | Tree loss: 0.451 | Accuracy: 0.866500 | 0.375 sec/iter
# Epoch: 493 | Batch: 009 / 011 | Total loss: 0.450 | Reg loss: 0.025 | Tree loss: 0.450 | Accuracy: 0.870500 | 0.375 sec/iter
# Epoch: 493 | Batch: 010 / 011 | Total loss: 0.507 | Reg loss: 0.025 | Tree loss: 0.507 | Accuracy: 0.829352 | 0.375 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 494 | Batch: 000 / 011 | Total loss: 0.574 | Reg loss: 0.025 | Tree loss: 0.574 | Accuracy: 0.818500 | 0.375 sec/iter
# Epoch: 494 | Batch: 001 / 011 | Total loss: 0.544 | Reg loss: 0.025 | Tree loss: 0.544 | Accuracy: 0.838000 | 0.375 sec/iter
# Epoch: 494 | Batch: 002 / 011 | Total loss: 0.546 | Reg loss: 0.025 | Tree loss: 0.546 | Accuracy: 0.807500 | 0.375 sec/iter
# Epoch: 494 | Batch: 003 / 011 | Total loss: 0.535 | Reg loss: 0.025 | Tree loss: 0.535 | Accuracy: 0.819000 | 0.375 sec/iter
# Epoch: 494 | Batch: 004 / 011 | Total loss: 0.509 | Reg loss: 0.025 | Tree loss: 0.509 | Accuracy: 0.826000 | 0.375 sec/iter
# Epoch: 494 | Batch: 005 / 011 | Total loss: 0.479 | Reg loss: 0.025 | Tree loss: 0.479 | Accuracy: 0.850500 | 0.375 sec/iter
# Epoch: 494 | Batch: 006 / 011 | Total loss: 0.477 | Reg loss: 0.025 | Tree loss: 0.477 | Accuracy: 0.855500 | 0.375 sec/iter
# Epoch: 494 | Batch: 007 / 011 | Total loss: 0.497 | Reg loss: 0.025 | Tree loss: 0.497 | Accuracy: 0.844000 | 0.375 sec/iter
# Epoch: 494 | Batch: 008 / 011 | Total loss: 0.456 | Reg loss: 0.025 | Tree loss: 0.456 | Accuracy: 0.863000 | 0.375 sec/iter
# Epoch: 494 | Batch: 009 / 011 | Total loss: 0.457 | Reg loss: 0.025 | Tree loss: 0.457 | Accuracy: 0.872000 | 0.375 sec/iter
# Epoch: 494 | Batch: 010 / 011 | Total loss: 0.475 | Reg loss: 0.025 | Tree loss: 0.475 | Accuracy: 0.843003 | 0.375 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 495 | Batch: 000 / 011 | Total loss: 0.572 | Reg loss: 0.025 | Tree loss: 0.572 | Accuracy: 0.818500 | 0.375 sec/iter
# Epoch: 495 | Batch: 001 / 011 | Total loss: 0.563 | Reg loss: 0.025 | Tree loss: 0.563 | Accuracy: 0.812500 | 0.375 sec/iter
# Epoch: 495 | Batch: 002 / 011 | Total loss: 0.541 | Reg loss: 0.025 | Tree loss: 0.541 | Accuracy: 0.814500 | 0.375 sec/iter
# Epoch: 495 | Batch: 003 / 011 | Total loss: 0.504 | Reg loss: 0.025 | Tree loss: 0.504 | Accuracy: 0.827500 | 0.375 sec/iter
# Epoch: 495 | Batch: 004 / 011 | Total loss: 0.513 | Reg loss: 0.025 | Tree loss: 0.513 | Accuracy: 0.832500 | 0.375 sec/iter
# Epoch: 495 | Batch: 005 / 011 | Total loss: 0.500 | Reg loss: 0.025 | Tree loss: 0.500 | Accuracy: 0.840000 | 0.375 sec/iter
# Epoch: 495 | Batch: 006 / 011 | Total loss: 0.463 | Reg loss: 0.025 | Tree loss: 0.463 | Accuracy: 0.860000 | 0.374 sec/iter
# Epoch: 495 | Batch: 007 / 011 | Total loss: 0.459 | Reg loss: 0.025 | Tree loss: 0.459 | Accuracy: 0.874000 | 0.374 sec/iter
# Epoch: 495 | Batch: 008 / 011 | Total loss: 0.483 | Reg loss: 0.025 | Tree loss: 0.483 | Accuracy: 0.850000 | 0.374 sec/iter
# Epoch: 495 | Batch: 009 / 011 | Total loss: 0.460 | Reg loss: 0.025 | Tree loss: 0.460 | Accuracy: 0.870000 | 0.374 sec/iter
# Epoch: 495 | Batch: 010 / 011 | Total loss: 0.452 | Reg loss: 0.025 | Tree loss: 0.452 | Accuracy: 0.883959 | 0.374 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 496 | Batch: 000 / 011 | Total loss: 0.592 | Reg loss: 0.025 | Tree loss: 0.592 | Accuracy: 0.808500 | 0.375 sec/iter
# Epoch: 496 | Batch: 001 / 011 | Total loss: 0.571 | Reg loss: 0.025 | Tree loss: 0.571 | Accuracy: 0.808500 | 0.375 sec/iter
# Epoch: 496 | Batch: 002 / 011 | Total loss: 0.548 | Reg loss: 0.025 | Tree loss: 0.548 | Accuracy: 0.802500 | 0.375 sec/iter
# Epoch: 496 | Batch: 003 / 011 | Total loss: 0.502 | Reg loss: 0.025 | Tree loss: 0.502 | Accuracy: 0.828000 | 0.375 sec/iter
# Epoch: 496 | Batch: 004 / 011 | Total loss: 0.482 | Reg loss: 0.025 | Tree loss: 0.482 | Accuracy: 0.843500 | 0.375 sec/iter
# Epoch: 496 | Batch: 005 / 011 | Total loss: 0.476 | Reg loss: 0.025 | Tree loss: 0.476 | Accuracy: 0.838500 | 0.375 sec/iter
# Epoch: 496 | Batch: 006 / 011 | Total loss: 0.480 | Reg loss: 0.025 | Tree loss: 0.480 | Accuracy: 0.854000 | 0.375 sec/iter
# Epoch: 496 | Batch: 007 / 011 | Total loss: 0.456 | Reg loss: 0.025 | Tree loss: 0.456 | Accuracy: 0.864000 | 0.375 sec/iter
# Epoch: 496 | Batch: 008 / 011 | Total loss: 0.481 | Reg loss: 0.025 | Tree loss: 0.481 | Accuracy: 0.859500 | 0.375 sec/iter
# Epoch: 496 | Batch: 009 / 011 | Total loss: 0.464 | Reg loss: 0.025 | Tree loss: 0.464 | Accuracy: 0.869500 | 0.374 sec/iter
# Epoch: 496 | Batch: 010 / 011 | Total loss: 0.516 | Reg loss: 0.025 | Tree loss: 0.516 | Accuracy: 0.849829 | 0.374 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 497 | Batch: 000 / 011 | Total loss: 0.589 | Reg loss: 0.025 | Tree loss: 0.589 | Accuracy: 0.818000 | 0.375 sec/iter
# Epoch: 497 | Batch: 001 / 011 | Total loss: 0.549 | Reg loss: 0.025 | Tree loss: 0.549 | Accuracy: 0.824000 | 0.375 sec/iter
# Epoch: 497 | Batch: 002 / 011 | Total loss: 0.532 | Reg loss: 0.025 | Tree loss: 0.532 | Accuracy: 0.817500 | 0.375 sec/iter
# Epoch: 497 | Batch: 003 / 011 | Total loss: 0.523 | Reg loss: 0.025 | Tree loss: 0.523 | Accuracy: 0.818000 | 0.375 sec/iter
# Epoch: 497 | Batch: 004 / 011 | Total loss: 0.483 | Reg loss: 0.025 | Tree loss: 0.483 | Accuracy: 0.839500 | 0.375 sec/iter
# Epoch: 497 | Batch: 005 / 011 | Total loss: 0.476 | Reg loss: 0.025 | Tree loss: 0.476 | Accuracy: 0.855500 | 0.375 sec/iter
# Epoch: 497 | Batch: 006 / 011 | Total loss: 0.497 | Reg loss: 0.025 | Tree loss: 0.497 | Accuracy: 0.849500 | 0.375 sec/iter
# Epoch: 497 | Batch: 007 / 011 | Total loss: 0.464 | Reg loss: 0.025 | Tree loss: 0.464 | Accuracy: 0.856500 | 0.374 sec/iter
# Epoch: 497 | Batch: 008 / 011 | Total loss: 0.466 | Reg loss: 0.025 | Tree loss: 0.466 | Accuracy: 0.865000 | 0.374 sec/iter
# Epoch: 497 | Batch: 009 / 011 | Total loss: 0.460 | Reg loss: 0.025 | Tree loss: 0.460 | Accuracy: 0.864500 | 0.374 sec/iter
# Epoch: 497 | Batch: 010 / 011 | Total loss: 0.542 | Reg loss: 0.025 | Tree loss: 0.542 | Accuracy: 0.822526 | 0.374 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 498 | Batch: 000 / 011 | Total loss: 0.575 | Reg loss: 0.025 | Tree loss: 0.575 | Accuracy: 0.818000 | 0.375 sec/iter
# Epoch: 498 | Batch: 001 / 011 | Total loss: 0.555 | Reg loss: 0.025 | Tree loss: 0.555 | Accuracy: 0.811500 | 0.375 sec/iter
# Epoch: 498 | Batch: 002 / 011 | Total loss: 0.536 | Reg loss: 0.025 | Tree loss: 0.536 | Accuracy: 0.815000 | 0.375 sec/iter
# Epoch: 498 | Batch: 003 / 011 | Total loss: 0.524 | Reg loss: 0.025 | Tree loss: 0.524 | Accuracy: 0.826500 | 0.375 sec/iter
# Epoch: 498 | Batch: 004 / 011 | Total loss: 0.489 | Reg loss: 0.025 | Tree loss: 0.489 | Accuracy: 0.842500 | 0.375 sec/iter
# Epoch: 498 | Batch: 005 / 011 | Total loss: 0.494 | Reg loss: 0.025 | Tree loss: 0.494 | Accuracy: 0.846500 | 0.375 sec/iter
# Epoch: 498 | Batch: 006 / 011 | Total loss: 0.480 | Reg loss: 0.025 | Tree loss: 0.480 | Accuracy: 0.858000 | 0.375 sec/iter
# Epoch: 498 | Batch: 007 / 011 | Total loss: 0.475 | Reg loss: 0.025 | Tree loss: 0.475 | Accuracy: 0.864000 | 0.375 sec/iter
# Epoch: 498 | Batch: 008 / 011 | Total loss: 0.467 | Reg loss: 0.025 | Tree loss: 0.467 | Accuracy: 0.862500 | 0.375 sec/iter
# Epoch: 498 | Batch: 009 / 011 | Total loss: 0.466 | Reg loss: 0.025 | Tree loss: 0.466 | Accuracy: 0.871500 | 0.375 sec/iter
# Epoch: 498 | Batch: 010 / 011 | Total loss: 0.500 | Reg loss: 0.025 | Tree loss: 0.500 | Accuracy: 0.805461 | 0.374 sec/iter
# Average sparseness: 0.9723756906077348
# layer 0: 0.9723756906077348
# layer 1: 0.9723756906077348
# layer 2: 0.9723756906077348
# layer 3: 0.9723756906077348
# layer 4: 0.9723756906077348
# layer 5: 0.9723756906077348
# layer 6: 0.9723756906077349
# Epoch: 499 | Batch: 000 / 011 | Total loss: 0.585 | Reg loss: 0.025 | Tree loss: 0.585 | Accuracy: 0.807500 | 0.375 sec/iter
# Epoch: 499 | Batch: 001 / 011 | Total loss: 0.569 | Reg loss: 0.025 | Tree loss: 0.569 | Accuracy: 0.818000 | 0.375 sec/iter
# Epoch: 499 | Batch: 002 / 011 | Total loss: 0.535 | Reg loss: 0.025 | Tree loss: 0.535 | Accuracy: 0.825500 | 0.375 sec/iter
# Epoch: 499 | Batch: 003 / 011 | Total loss: 0.510 | Reg loss: 0.025 | Tree loss: 0.510 | Accuracy: 0.826000 | 0.375 sec/iter
# Epoch: 499 | Batch: 004 / 011 | Total loss: 0.489 | Reg loss: 0.025 | Tree loss: 0.489 | Accuracy: 0.842500 | 0.375 sec/iter
# Epoch: 499 | Batch: 005 / 011 | Total loss: 0.489 | Reg loss: 0.025 | Tree loss: 0.489 | Accuracy: 0.839000 | 0.375 sec/iter
# Epoch: 499 | Batch: 006 / 011 | Total loss: 0.497 | Reg loss: 0.025 | Tree loss: 0.497 | Accuracy: 0.846500 | 0.375 sec/iter
# Epoch: 499 | Batch: 007 / 011 | Total loss: 0.456 | Reg loss: 0.025 | Tree loss: 0.456 | Accuracy: 0.869500 | 0.375 sec/iter
# Epoch: 499 | Batch: 008 / 011 | Total loss: 0.470 | Reg loss: 0.025 | Tree loss: 0.470 | Accuracy: 0.863000 | 0.375 sec/iter
# Epoch: 499 | Batch: 009 / 011 | Total loss: 0.447 | Reg loss: 0.025 | Tree loss: 0.447 | Accuracy: 0.879000 | 0.375 sec/iter
# Epoch: 499 | Batch: 010 / 011 | Total loss: 0.421 | Reg loss: 0.025 | Tree loss: 0.421 | Accuracy: 0.883959 | 0.375 sec/iter

# %%
plt.figure(figsize=(10, 5))
plt.ylabel("Accuracy")
plt.xlabel('Iteration')
plt.plot(accs, label='Accuracy vs iteration')
plt.show()

# %%
plt.figure()
plt.ylabel("Loss")
plt.xlabel('Iteration')
plt.plot(losses, label='Loss vs iteration')
plt.yscale("log")
plt.show()

plt.figure()
weights = tree.inner_nodes.weight.cpu().detach().numpy().flatten()
plt.hist(weights, bins=500)
weights_std = np.std(weights)
weights_mean = np.mean(weights)
plt.axvline(weights_mean + weights_std, color='r')
plt.axvline(weights_mean - weights_std, color='r')
plt.title(f"Mean: {weights_mean}   |   STD: {weights_std}")
plt.yscale("log")
plt.show()

# %% [markdown]
# # Tree Visualization

# %%
plt.figure(figsize=(15, 10), dpi=80)
avg_height, root = tree.visualize()
# Out:
# Average height: 6.517241379310345

# %% [markdown]
# # Extract Rules

# %% [markdown]
# # Accumulate samples in the leaves

# %%
print(f"Number of patterns: {len(root.get_leaves())}")
# Out:
# Number of patterns: 29

# %%
method = 'MLE'

# %%
root.clear_leaves_samples()

with torch.no_grad():
    for batch_idx, (data, target) in enumerate(tree_loader):
        root.accumulate_samples(data, method)
# Out:
# /home/eitan.k/.local/lib/python3.6/site-packages/torch/nn/functional.py:1709: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %% [markdown]
# # Tighten boundaries

# %%
signal_names = dataset.dataset.all_signals
normalizers = torch.tensor([])
attr_names = []
for signal_name in signal_names:
    attr_names += [f"T{i}.{signal_name}" for i in range(sampled.shape[-1])]
    sensor_norm = torch.tensor([torch.tensor(dataset.dataset.sensor_maxs[signal_name]) for _ in range(sampled.shape[-1])])
    normalizers = torch.cat([normalizers, sensor_norm])
    

# print(attr_names)
leaves = root.get_leaves()
sum_comprehensibility = 0

for pattern_counter, leaf in enumerate(leaves):
    leaf.reset_path()
    leaf.tighten_with_accumulated_samples()
    conds = leaf.get_path_conditions(attr_names)
    for cond in conds:
        cond.weights = cond.weights / normalizers
    print(f"============== Pattern {pattern_counter + 1} ==============")
    sum_comprehensibility += sum([cond.comprehensibility for cond in conds])
    
print(f"Average comprehensibility: {sum_comprehensibility / len(leaves)}")
# Out:
# ============== Pattern 1 ==============
# ============== Pattern 2 ==============
# ============== Pattern 3 ==============
# ============== Pattern 4 ==============
# ============== Pattern 5 ==============
# ============== Pattern 6 ==============
# ============== Pattern 7 ==============
# ============== Pattern 8 ==============
# ============== Pattern 9 ==============
# ============== Pattern 10 ==============
# ============== Pattern 11 ==============
# ============== Pattern 12 ==============
# ============== Pattern 13 ==============
# ============== Pattern 14 ==============
# ============== Pattern 15 ==============
# ============== Pattern 16 ==============
# ============== Pattern 17 ==============
# ============== Pattern 18 ==============
# ============== Pattern 19 ==============
# ============== Pattern 20 ==============
# ============== Pattern 21 ==============
# ============== Pattern 22 ==============
# ============== Pattern 23 ==============
# ============== Pattern 24 ==============
# ============== Pattern 25 ==============
# ============== Pattern 26 ==============
# ============== Pattern 27 ==============
# ============== Pattern 28 ==============
# ============== Pattern 29 ==============
# Average comprehensibility: 59.6551724137931
# /home/eitan.k/EntangledExplainableClustering/soft_decision_tree/sdt_model.py:14: RuntimeWarning: divide by zero encountered in log
#   return np.log(1 / (1 - x))

# %%
# prune_tree(tree, factor=1.5)
correct = 0
tree = tree.eval()
with torch.no_grad():
    for batch_idx, (data, target) in enumerate(tree_loader):
            data, target = data.to(device), target.to(device)
            output = tree.forward(data)
            pred = output.data.max(1)[1]
            correct += pred.eq(target.view(-1).data).sum()

print(f"Accuracy: {correct / len(tree_loader.dataset)}")

# %%
print(f"Sparseness: {sparseness(tree.inner_nodes.weight)}")
layer = 0
sps = []
for i in range(tree.inner_nodes.weight.shape[0]):
    cur_layer = np.floor(np.log2(i+1))
    if cur_layer != layer:
        print(f"layer {layer}: {np.mean(sps)}")
        sps = []
        layer = cur_layer
    
    x_ = tree.inner_nodes.weight[i, :]
    sp = (len(x_) - torch.norm(x_, 0).item()) / len(x_)
    sps.append(sp)

# %% [markdown]
# ## Prune the weights

# %%
weights = tree.inner_nodes.weight.cpu().detach().numpy()
for i in range(0, weights.shape[0], 20):
    plt.figure()
    weights_layer = weights[i, :]
    plt.hist(weights_layer, bins=500)
    weights_std = np.std(weights_layer)
    weights_mean = np.mean(weights_layer)
    plt.axvline(weights_mean + weights_std, color='r')
    plt.axvline(weights_mean - weights_std, color='r')
    plt.title(f"Mean: {weights_mean}   |   STD: {weights_std}\n Kurtosis: {kurtosis(weights_layer)}")
    plt.yscale("log")
    plt.show()

# %% [markdown]
# ## Verify that the accuracy didn't change too much

# %%
correct = 0
tree_copy = tree_copy.eval()
with torch.no_grad():
    for batch_idx, (data, target) in enumerate(tree_loader):
            data, target = data.to(device), target.to(device)
            output = tree_copy.forward(data)
            pred = output.data.max(1)[1]
            correct += pred.eq(target.view(-1).data).sum()

print(f"Accuracy: {correct / len(tree_loader.dataset)}")

# %%
weights = tree_copy.inner_nodes.weight.cpu().detach().numpy()
for i in range(0, weights.shape[0], 20):
    plt.figure()
    weights_layer = weights[i, :]
    plt.hist(weights_layer, bins=500)
    weights_std = np.std(weights_layer)
    weights_mean = np.mean(weights_layer)
    plt.axvline(weights_mean + weights_std, color='r')
    plt.axvline(weights_mean - weights_std, color='r')
    plt.title(f"Mean: {weights_mean}   |   STD: {weights_std}")
    plt.yscale("log")
    plt.show()

# %%
stack = LifoQueue()
edge_stack = LifoQueue()
stack.put(root)
rule_counter = 0
root.reset()
while not stack.empty():
    node = stack.get()
    if node.is_leaf():
        print(f"============== Rule {rule_counter} ==============")
        for stack_node, cond in zip(stack.queue, edge_stack.queue[1:]):
            print(repr(stack_node.get_condition(attr_names)) + cond)
            print()
        
        rule_counter += 1
        edge_stack.get()
        continue
          
    if node.left is not None and not node.left.visited:
        stack.put(node)
        stack.put(node.left)
        node.left.visited = True
        edge_stack.put(' < 0')
        continue
        
    if node.right is not None and not node.right.visited:
        stack.put(node)
        stack.put(node.right)
        node.right.visited = True
        edge_stack.put(' > 0')
        continue
        
    if node is not root:
        edge_stack.get()
